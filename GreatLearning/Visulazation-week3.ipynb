# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from warnings import filterwarnings
filterwarnings("ignore")

# %%
tips =sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
sns.displot(x=tips["size"],bins=4)

# %%
sns.displot(x=tips["total_bill"],bins=20,kde=True)

# %%
sns.boxplot(x=tips["total_bill"])
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.countplot(x=tips["sex"])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
plt.pie(tips["day"].value_counts(),labels=tips["day"].value_counts().index)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f9e06d518e0>,
#   <matplotlib.patches.Wedge at 0x7f9e06d517f0>,
#   <matplotlib.patches.Wedge at 0x7f9e06d5a250>,
#   <matplotlib.patches.Wedge at 0x7f9e06d5a520>],
#  [Text(0.47909423581850485, 0.990186201280084, 'Sat'),
#   Text(-1.0967192869113325, -0.08489290734035711, 'Sun'),
#   Text(0.3074340394718735, -1.0561649072820052, 'Thur'),
#   Text(1.06724906774893, -0.2664196452760947, 'Fri')])

# %%
sns.scatterplot(x=tips["total_bill"],y=tips["tip"])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(data=tips,x="total_bill",y="tip")

# %%
sns.jointplot(data=tips,x="total_bill",y="tip")

# %%
sns.boxplot(x=tips["day"],y=tips["total_bill"])
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
ct = pd.crosstab(tips["sex"],tips["smoker"])
ct
# Out:
# smoker  Yes  No
# sex
# Male     60  97
# Female   33  54

# %%
ct.plot(kind="bar",stacked=True)
# Out:
# <Axes: xlabel='sex'>
