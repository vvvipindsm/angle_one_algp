# %% [markdown]
# # Import libraries and data

# %%
# %cd /content/drive/MyDrive/Forecasting Models and Time Series for Business in Python
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/Forecasting Models and Time Series for Business in Python'
# /Users/vipin/workspace/ai/my_own/Forecasting Models and Time Series for Business in Python 2/3. Holt-Winters

# %%
#import libraries
import pandas as pd
import numpy as np

# %%
#get the data
data = pd.read_csv("../Daily Bike Sharing.csv", 
                   index_col = "dteday", 
                   parse_dates = True)
data.head()
# Out:
#             instant  season  yr  mnth  holiday  weekday  workingday  \
# dteday
# 2011-01-01        1       1   0     1        0        6           0
# 2011-01-02        2       1   0     1        0        0           0
# 2011-01-03        3       1   0     1        0        1           1
# 2011-01-04        4       1   0     1        0        2           1
# 2011-01-05        5       1   0     1        0        3           1
#
#             weathersit      temp     atemp       hum  windspeed  casual  \
# dteday
# 2011-01-01           2  0.344167  0.363625  0.805833   0.160446     331
# 2011-01-02           2  0.363478  0.353739  0.696087   0.248539     131
# 2011-01-03           1  0.196364  0.189405  0.437273   0.248309     120
# 2011-01-04           1  0.200000  0.212122  0.590435   0.160296     108
# 2011-01-05           1  0.226957  0.229270  0.436957   0.186900      82
#
#             registered   cnt
# dteday
# 2011-01-01         654   985
# 2011-01-02         670   801
# 2011-01-03        1229  1349
# 2011-01-04        1454  1562
# 2011-01-05        1518  1600

# %%
#select variables
dataset = data.loc[:, ["cnt", "holiday", "workingday", "weathersit",
                       "temp", "atemp", "hum", "windspeed"]]
dataset.head(1)
# Out:
#             cnt  holiday  workingday  weathersit      temp     atemp  \
# dteday
# 2011-01-01  985        0           0           2  0.344167  0.363625
#
#                  hum  windspeed
# dteday
# 2011-01-01  0.805833   0.160446

# %% [markdown]
# #Data Transformation

# %%
#renaming variable
dataset = dataset.rename(columns = {'cnt' : 'y'})
dataset.head(1)
# Out:
#               y  holiday  workingday  weathersit      temp     atemp  \
# dteday
# 2011-01-01  985        0           0           2  0.344167  0.363625
#
#                  hum  windspeed
# dteday
# 2011-01-01  0.805833   0.160446

# %%
#index
dataset = dataset.asfreq("D")
dataset.index
# Out:
# DatetimeIndex(['2011-01-01', '2011-01-02', '2011-01-03', '2011-01-04',
#                '2011-01-05', '2011-01-06', '2011-01-07', '2011-01-08',
#                '2011-01-09', '2011-01-10',
#                ...
#                '2012-12-22', '2012-12-23', '2012-12-24', '2012-12-25',
#                '2012-12-26', '2012-12-27', '2012-12-28', '2012-12-29',
#                '2012-12-30', '2012-12-31'],
#               dtype='datetime64[ns]', name='dteday', length=731, freq='D')

# %% [markdown]
# #Visualization

# %%
#viz
dataset["y"].plot(figsize = (10, 7), legend = True)
# Out:
# <Axes: xlabel='dteday'>

# %% [markdown]
# #Training and Test Set

# %%
#Training and test set
test_days = 31
training_set = dataset.iloc[:-test_days, :]
test_set = dataset.iloc[-test_days:, :]
test_set.tail(1)
# Out:
#                y  holiday  workingday  weathersit      temp     atemp     hum  \
# dteday
# 2012-12-31  2729        0           1           2  0.215833  0.223487  0.5775
#
#             windspeed
# dteday
# 2012-12-31   0.154846

# %% [markdown]
# #Holt-Winters

# %%
#libraries
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
#forecasting model
model = ExponentialSmoothing(endog = training_set.y,
                             trend = 'mul',
                             seasonal = 'mul',
                             seasonal_periods = 7).fit()
# Out:
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
#predictions
predictions_hw = model.forecast(steps = len(test_set)).rename("HW")
predictions_hw.head()
# Out:
# 2012-12-01    4788.938080
# 2012-12-02    4518.964763
# 2012-12-03    4492.669228
# 2012-12-04    4567.879403
# 2012-12-05    4624.998747
# Freq: D, Name: HW, dtype: float64

# %%
#visualization
training_set['y']['2012-07-01':].plot(figsize = (9,6), legend = True)
test_set['y'].plot(legend = True)
predictions_hw.plot(legend = True)
# Out:
# <Axes: xlabel='dteday'>

# %% [markdown]
# #Model assessment

# %%
#MAE and RMSE
from sklearn.metrics import mean_squared_error, mean_absolute_error
print(round(mean_absolute_error(test_set['y'], predictions_hw),0))
print(round(np.sqrt(mean_squared_error(test_set['y'], predictions_hw)), 0))
# Out:
# 1440.0
# 1750.0

# %%
#MAPE function
def MAPE(y_true, y_pred):
  y_true, y_pred = np.array(y_true), np.array(y_pred)
  return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
MAPE(test_set['y'], predictions_hw)
# Out:
# 90.36109533487513

# %% [markdown]
# #export forecasts

# %%
# %cd /content/drive/MyDrive/Forecasting Models and Time Series for Business in Python/0. Ensemble
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/Forecasting Models and Time Series for Business in Python/0. Ensemble'
# /Users/vipin/workspace/ai/my_own/Forecasting Models and Time Series for Business in Python 2/3. Holt-Winters

# %%
predictions_hw.to_csv('predictions_hw.csv', index = True)
