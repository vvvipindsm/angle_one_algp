# %% [markdown]
# ### Case Study

# %% [markdown]
# The VIX is a measure of the implied volatility for the S&P500. The higher the "Close" of the VIX, the higher the uncertainty in the market. Fortunately, there are ways of capitlizing on the predictability of the VIX. Being able to predict implied volatility for the market with any degree of certainty better than 50/50 can give an options trader of ETF trader (VIX tracking ETF's) an edge.
#
# There could be many, many features that impact whether a stock price goes up or down. Predicting directionality for stocks, the VIX, commodities, FX etc represents a huge potential gain for every small percentage increment in forecast ability.
#
# However, having so many features allows room for noise and can create adverse impacts to your supervised learning. Therefore, we will explore deplying PCA (Principle Component Analysis) as a tool to find useful information within a vast array of indicators and features to help with our supervised learning later on.
#
# PCA can equally be extremely good at helping to understand correlations too and further study on PCS (based on articles and papers below) is encorouged.

# %% [markdown]
# ### Imports

# %%
# Remove unwanted warnings
import warnings

warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=RuntimeWarning)

# Data Management
import pandas as pd
import numpy as np
from sklearn import tree

from ta import add_all_ta_features
from numpy import cumsum, log, polyfit, sqrt, std, subtract
import sklearn.mixture as mix
# Statistics
from statsmodels.tsa.stattools import adfuller

# Unsupervised Machine Learning
from sklearn.decomposition import PCA

# Supervised Machine Learning
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
import pickle

# Reporting
import matplotlib.pyplot as plt
import yfinance
from matplotlib.pylab import rcParams
from xgboost import plot_tree

# %%
def hurst(ts, min_lag=1, max_lag=100):
    lags = range(min_lag, max_lag)
    tau = [sqrt(std(subtract(ts[lag:], ts[:-lag]))) for lag in lags]
    poly = polyfit(log(lags), log(tau), 1)
    return poly[0]*2.0

# %%
findFeature = True
#[OLECTRA,"LT","CONCOR","ELGIEQUIP","IOC","BEL","TATAELXSI","^NSEI"]
stock_name = "IOC.NS"
disableStationaryCheck = False
features = []
if findFeature == False:
    with open('./TrainedModel/indicator/{}_features.txt'.format(stock_name), 'rb') as f:
            features = pickle.load(f)
            print(feature_item)
            features.append("TARGET")

# %% [markdown]
# ### Initial Data Extraction

# %%
# Data Extraction
start_date = "2017-01-01"
end_date = "2022-06-01"
#symbol = "IOC.NS"

#df = yfinance.download(tickers = stock_name,start="2010-03-06",
 #                              interval = "1d", group_by = 'ticker', auto_adjust = True)

df = pd.read_csv("./stock_historical_data/{}.csv".format(stock_name))
df.set_index("Date", inplace=True)

df = df[["Open", "High", "Low", "Close","Volume"]]
df.tail()
# Out:
#                   Open        High        Low      Close    Volume
# Date
# 2023-07-04   96.000000   96.400002  94.349998  94.650002  11918401
# 2023-07-05   95.150002   95.699997  93.400002  95.500000  14283796
# 2023-07-06   96.000000   98.800003  96.000000  98.599998  32778334
# 2023-07-07   99.449997  101.250000  98.800003  99.199997  37546405
# 2023-07-10  101.000000  101.449997  97.099998  97.400002  24037673

# %%
df_nifty = pd.read_csv("./stock_historical_data/{}.csv".format("^NSEI"))
df_nifty.set_index("Date", inplace=True)

df_nifty = df_nifty[["Open", "High", "Low", "Close","Volume"]]
df_nifty.tail()
# Out:
#                     Open          High           Low         Close  Volume
# Date
# 2023-07-04  19406.599609  19434.150391  19300.000000  19389.000000  226900
# 2023-07-05  19405.949219  19421.599609  19339.599609  19398.500000  224400
# 2023-07-06  19385.699219  19512.199219  19373.000000  19497.300781  268300
# 2023-07-07  19422.800781  19523.599609  19303.599609  19331.800781  237100
# 2023-07-10  19400.349609  19435.849609  19327.099609  19355.900391       0

# %%
df["NiftyReturn"] = df_nifty["Close"].pct_change()

# %%
#check last day positive return or not
new_df = []
new_df_1 = []

for i in range(0,len(df)):
    if i < 2:
        new_df.append(np.nan)
    else:
        if df.iloc[i-1].Open < df.iloc[i-1].Close:
            new_df.append(1)
        else:
            new_df.append(0)
        if df.iloc[i-1].Open < df.iloc[i-1].Close and df.iloc[i-2].Open < df.iloc[i-2].Close:
            new_df_1.append(1)
        else:
            new_df_1.append(0)

# %%
df["previous_day"] = new_df

# %%
df = df.dropna()

# %%
# Add TA
df = add_all_ta_features(df, open="Open", high="High", low="Low", close="Close", volume="Volume", fillna=True)
# Out:
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volume_adi"] = AccDistIndexIndicator(
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volume_obv"] = OnBalanceVolumeIndicator(
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volume_cmf"] = ChaikinMoneyFlowIndicator(
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volume_fi"] = ForceIndexIndicator(
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:114: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volume_em"] = indicator_eom.ease_of_movement()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:115: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volume_sma_em"] = indicator_eom.sma_ease_of_movement()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:118: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volume_vpt"] = VolumePriceTrendIndicator(
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:123: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volume_vwap"] = VolumeWeightedAveragePrice(
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:134: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volume_mfi"] = MFIIndicator(
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volume_nvi"] = NegativeVolumeIndexIndicator(
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volatility_bbm"] = indicator_bb.bollinger_mavg()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:180: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volatility_bbh"] = indicator_bb.bollinger_hband()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volatility_bbl"] = indicator_bb.bollinger_lband()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:182: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volatility_bbw"] = indicator_bb.bollinger_wband()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:183: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volatility_bbp"] = indicator_bb.bollinger_pband()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volatility_bbhi"] = indicator_bb.bollinger_hband_indicator()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:185: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volatility_bbli"] = indicator_bb.bollinger_lband_indicator()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volatility_kcc"] = indicator_kc.keltner_channel_mband()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:192: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volatility_kch"] = indicator_kc.keltner_channel_hband()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:193: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volatility_kcl"] = indicator_kc.keltner_channel_lband()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volatility_kcw"] = indicator_kc.keltner_channel_wband()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:195: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volatility_kcp"] = indicator_kc.keltner_channel_pband()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:196: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volatility_kchi"] = indicator_kc.keltner_channel_hband_indicator()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volatility_kcli"] = indicator_kc.keltner_channel_lband_indicator()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volatility_dcl"] = indicator_dc.donchian_channel_lband()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volatility_dch"] = indicator_dc.donchian_channel_hband()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volatility_dcm"] = indicator_dc.donchian_channel_mband()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:206: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volatility_dcw"] = indicator_dc.donchian_channel_wband()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volatility_dcp"] = indicator_dc.donchian_channel_pband()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volatility_atr"] = AverageTrueRange(
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:216: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volatility_ui"] = UlcerIndex(
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:251: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_macd"] = indicator_macd.macd()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:252: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_macd_signal"] = indicator_macd.macd_signal()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:253: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_macd_diff"] = indicator_macd.macd_diff()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_sma_fast"] = SMAIndicator(
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:259: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_sma_slow"] = SMAIndicator(
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:264: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_ema_fast"] = EMAIndicator(
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:267: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_ema_slow"] = EMAIndicator(
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:275: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_vortex_ind_pos"] = indicator_vortex.vortex_indicator_pos()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:276: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_vortex_ind_neg"] = indicator_vortex.vortex_indicator_neg()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:277: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_vortex_ind_diff"] = indicator_vortex.vortex_indicator_diff()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:280: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_trix"] = TRIXIndicator(
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:285: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_mass_index"] = MassIndex(
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:290: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_dpo"] = DPOIndicator(
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_kst"] = indicator_kst.kst()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:309: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_kst_sig"] = indicator_kst.kst_sig()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:310: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_kst_diff"] = indicator_kst.kst_diff()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_ichimoku_conv"] = indicator_ichi.ichimoku_conversion_line()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:323: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_ichimoku_base"] = indicator_ichi.ichimoku_base_line()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:324: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_ichimoku_a"] = indicator_ichi.ichimoku_a()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:325: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_ichimoku_b"] = indicator_ichi.ichimoku_b()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:328: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_stc"] = STCIndicator(
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:343: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_adx"] = indicator_adx.adx()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:344: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_adx_pos"] = indicator_adx.adx_pos()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:345: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_adx_neg"] = indicator_adx.adx_neg()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:348: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_cci"] = CCIIndicator(
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:367: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_visual_ichimoku_a"] = indicator_ichi_visual.ichimoku_a()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:368: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_visual_ichimoku_b"] = indicator_ichi_visual.ichimoku_b()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:372: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_aroon_up"] = indicator_aroon.aroon_up()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:373: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_aroon_down"] = indicator_aroon.aroon_down()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:374: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_aroon_ind"] = indicator_aroon.aroon_indicator()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:386: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_psar_up"] = indicator_psar.psar_up()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:387: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_psar_down"] = indicator_psar.psar_down()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:388: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_psar_up_indicator"] = indicator_psar.psar_up_indicator()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:389: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}trend_psar_down_indicator"] = indicator_psar.psar_down_indicator()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:421: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}momentum_rsi"] = RSIIndicator(
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:429: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}momentum_stoch_rsi"] = indicator_srsi.stochrsi()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:430: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}momentum_stoch_rsi_k"] = indicator_srsi.stochrsi_k()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:431: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}momentum_stoch_rsi_d"] = indicator_srsi.stochrsi_d()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:434: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}momentum_tsi"] = TSIIndicator(
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:439: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}momentum_uo"] = UltimateOscillator(
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:461: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}momentum_stoch"] = indicator_so.stoch()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}momentum_stoch_signal"] = indicator_so.stoch_signal()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}momentum_wr"] = WilliamsRIndicator(
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:470: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}momentum_ao"] = AwesomeOscillatorIndicator(
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:475: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}momentum_roc"] = ROCIndicator(
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:483: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}momentum_ppo"] = indicator_ppo.ppo()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:484: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}momentum_ppo_signal"] = indicator_ppo.ppo_signal()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:485: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}momentum_ppo_hist"] = indicator_ppo.ppo_hist()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:491: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}momentum_pvo"] = indicator_pvo.pvo()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:492: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}momentum_pvo_signal"] = indicator_pvo.pvo_signal()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:493: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}momentum_pvo_hist"] = indicator_pvo.pvo_hist()
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:497: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}momentum_kama"] = KAMAIndicator(
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:522: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}others_dr"] = DailyReturnIndicator(
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:527: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}others_dlr"] = DailyLogReturnIndicator(
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/wrapper.py:532: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}others_cr"] = CumulativeReturnIndicator(

# %%
df  = df.dropna()

# %% [markdown]
# ### Data Preprocessing - Stationarity

# %%
# Identify non-stationary columns

non_stationaries = []
for col in df.columns:
    dftest = adfuller(df[col].values)
    p_value = dftest[1]
    t_test = dftest[0] < dftest[4]["1%"]
    if p_value > 0.05 or not t_test:
        non_stationaries.append(col)
print(f"Non-Stationary Features Found: {len(non_stationaries)}")
# Out:
# Non-Stationary Features Found: 30

# %%
df_stationary = df.copy()
df_stationary[non_stationaries] = df_stationary[non_stationaries].pct_change()
df_stationary = df_stationary.iloc[1:]

# %%
# Find NaN Rows
na_list = df_stationary.columns[df_stationary.isna().any().tolist()]
df_stationary.drop(columns=na_list, inplace=True)

# %%
# Handle inf values
df_stationary.replace([np.inf, -np.inf], 0, inplace=True)

df_stationary.head()
# Out:
#                 Open      High       Low     Close    Volume  NiftyReturn  \
# Date
# 2007-09-20 -0.002692  0.025063  0.009472  0.032075   6017016     0.003212
# 2007-09-21  0.034447  0.007656  0.033419  0.014104   3898452     0.018957
# 2007-09-24  0.013295  0.010172  0.002239 -0.005292   2784420     0.019566
# 2007-09-25  0.000613  0.066966  0.012658  0.077951  14686152     0.001348
# 2007-09-26  0.069608  0.098352  0.068628  0.074725  14155368     0.000334
#
#             volume_adi  volume_obv  volume_cmf     volume_fi  ...  \
# Date                                                          ...
# 2007-09-20   -3.864488    3.532580    0.265233  3.244500e+06  ...
# 2007-09-21    0.793247    0.504961    0.316040  2.917282e+06  ...
# 2007-09-24   -0.561544   -0.239649    0.111781  2.463488e+06  ...
# 2007-09-25    6.737194    1.662394    0.428231  4.973864e+06  ...
# 2007-09-26    0.418272    0.601831    0.408543  7.114152e+06  ...
#
#             momentum_ppo_signal  momentum_ppo_hist  momentum_pvo  \
# Date
# 2007-09-20             0.051053           0.204212     17.011574
# 2007-09-21             0.154110           0.412229     20.390609
# 2007-09-24             0.274956           0.483384     19.142860
# 2007-09-25             0.526072           1.004461     43.197935
# 2007-09-26             0.969484           1.773650     51.262689
#
#             momentum_pvo_signal  momentum_pvo_hist  momentum_kama  others_dr  \
# Date
# 2007-09-20             3.402315          13.609259       0.011505   3.207529
# 2007-09-21             6.799974          13.590636       0.012315   1.410379
# 2007-09-24             9.268551           9.874309       0.006225  -0.529222
# 2007-09-25            16.054428          27.143507       0.034268   7.795073
# 2007-09-26            23.096080          28.166609       0.046844   7.472492
#
#             others_dlr  others_cr  previous_day
# Date
# 2007-09-20    3.157162   0.000000           0.0
# 2007-09-21    1.400525   0.453813           1.0
# 2007-09-24   -0.530627  -0.118783           1.0
# 2007-09-25    7.506176   1.974910           0.0
# 2007-09-26    7.206474   0.685990           1.0
#
# [5 rows x 93 columns]

# %% [markdown]
# ### Data Preprocessing - Scaling and Target Setting

# %%
# Set Target (for Supervised ML later on)
df_stationary["TARGET"] = -1
df_stationary.loc[df_stationary["Close"].shift(-1) > df_stationary["Close"], "TARGET"] = 1
df_stationary.dropna(inplace=True)

# %%
df_stationary
# Out:
#                 Open      High       Low     Close    Volume  NiftyReturn  \
# Date
# 2007-09-20 -0.002692  0.025063  0.009472  0.032075   6017016     0.003212
# 2007-09-21  0.034447  0.007656  0.033419  0.014104   3898452     0.018957
# 2007-09-24  0.013295  0.010172  0.002239 -0.005292   2784420     0.019566
# 2007-09-25  0.000613  0.066966  0.012658  0.077951  14686152     0.001348
# 2007-09-26  0.069608  0.098352  0.068628  0.074725  14155368     0.000334
# ...              ...       ...       ...       ...       ...          ...
# 2023-07-04  0.048035  0.003122  0.033406 -0.006299  11918401     0.003439
# 2023-07-05 -0.008854 -0.007261 -0.010069  0.008980  14283796     0.000490
# 2023-07-06  0.008933  0.032393  0.027837  0.032461  32778334     0.005093
# 2023-07-07  0.035937  0.024798  0.029167  0.006085  37546405    -0.008488
# 2023-07-10  0.015586  0.001975 -0.017207 -0.018145  24037673     0.001247
#
#             volume_adi  volume_obv  volume_cmf     volume_fi  ...  \
# Date                                                          ...
# 2007-09-20   -3.864488    3.532580    0.265233  3.244500e+06  ...
# 2007-09-21    0.793247    0.504961    0.316040  2.917282e+06  ...
# 2007-09-24   -0.561544   -0.239649    0.111781  2.463488e+06  ...
# 2007-09-25    6.737194    1.662394    0.428231  4.973864e+06  ...
# 2007-09-26    0.418272    0.601831    0.408543  7.114152e+06  ...
# ...                ...         ...         ...           ...  ...
# 2023-07-04    0.003357   -0.002552   -0.112549  1.538097e+07  ...
# 2023-07-05   -0.004682    0.003067   -0.065657  1.491815e+07  ...
# 2023-07-06   -0.011202    0.007016    0.013337  2.730310e+07  ...
# 2023-07-07    0.010196    0.007980   -0.057824  2.662091e+07  ...
# 2023-07-10    0.008271   -0.005069   -0.095814  1.663682e+07  ...
#
#             momentum_ppo_hist  momentum_pvo  momentum_pvo_signal  \
# Date
# 2007-09-20           0.204212     17.011574             3.402315
# 2007-09-21           0.412229     20.390609             6.799974
# 2007-09-24           0.483384     19.142860             9.268551
# 2007-09-25           1.004461     43.197935            16.054428
# 2007-09-26           1.773650     51.262689            23.096080
# ...                       ...           ...                  ...
# 2023-07-04           0.025997      7.468138             1.367941
# 2023-07-05           0.190846      7.316330             2.557619
# 2023-07-06           0.482270     16.807107             5.407517
# 2023-07-07           0.662005     24.363226             9.198659
# 2023-07-10           0.599176     23.776012            12.114129
#
#             momentum_pvo_hist  momentum_kama  others_dr  others_dlr  \
# Date
# 2007-09-20          13.609259       0.011505   3.207529    3.157162
# 2007-09-21          13.590636       0.012315   1.410379    1.400525
# 2007-09-24           9.874309       0.006225  -0.529222   -0.530627
# 2007-09-25          27.143507       0.034268   7.795073    7.506176
# 2007-09-26          28.166609       0.046844   7.472492    7.206474
# ...                       ...            ...        ...         ...
# 2023-07-04           6.100197       0.002535  -0.629920   -0.631912
# 2023-07-05           4.758711       0.003827   0.898044    0.894035
# 2023-07-06          11.399591       0.010552   3.246072    3.194500
# 2023-07-07          15.164568       0.010686   0.608518    0.606674
# 2023-07-10          11.661883       0.008810  -1.814512   -1.831176
#
#             others_cr  previous_day  TARGET
# Date
# 2007-09-20   0.000000           0.0      -1
# 2007-09-21   0.453813           1.0      -1
# 2007-09-24  -0.118783           1.0       1
# 2007-09-25   1.974910           0.0      -1
# 2007-09-26   0.685990           1.0      -1
# ...               ...           ...     ...
# 2023-07-04  -0.007649           1.0       1
# 2023-07-05   0.010920           0.0       1
# 2023-07-06   0.039396           1.0      -1
# 2023-07-07   0.007336           1.0      -1
# 2023-07-10  -0.021848           0.0      -1
#
# [3872 rows x 94 columns]

# %%
# Convert non-stationaries to stationary
#if findFeature == False:
df_stationary = df_stationary[['High','Low', 'Close', 'volume_adi', 'volume_obv', 'volume_vpt', 'volatility_kcp', 'trend_ema_slow', 'others_dr', 'others_dlr', 'others_cr','previous_day', 'NiftyReturn','TARGET']]

# %%
# Split Target from Featureset
X = df_stationary.iloc[:, :-1]
y = df_stationary.iloc[:, -1]

# %%
# Feature Scaling
df_sc = df_stationary.copy()
X_fs = StandardScaler().fit_transform(X)

# %%
# Train Test Split
X_train, X_test, y_train, y_test = train_test_split(X_fs, y, test_size=0.7, random_state=42)

# %% [markdown]
# ### Unsupervised ML - PCA Dimensionality Reduction

# %% [markdown]
# ### Supervised ML - Random Forest Classification

# %%
classifier = RandomForestClassifier(n_estimators=12, max_depth=2, random_state=0)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
print(f"Test Accuracy: {accuracy}")
print(f"Test Precision: {precision}")
# Out:
# Test Accuracy: 0.7347842124677241
# Test Precision: 0.7585917854149203

# %%
# Plot Feature Importances
fig = plt.figure(figsize=(22, 5))
importance_labels = X.columns
importance_features = classifier.feature_importances_
plt.bar(importance_labels, importance_features)
plt.show()

# %%
# Select Best Features
mean_feature_importance = importance_features.mean()
i = 0
recommended_feature_labels = []
recommended_feature_score = []
for fi in importance_features:
    if fi > mean_feature_importance:
        recommended_feature_labels.append(importance_labels[i])
        recommended_feature_score.append(fi)
    i += 1

# %%
fig, ax = plt.subplots(figsize=(35, 6))

ax.bar(recommended_feature_labels, recommended_feature_score)
fig.show()
# Out:
# /var/folders/4_/_fbkdkz531s_92lxx_c_x6n00000gn/T/ipykernel_793/3002898103.py:4: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
recommended_feature_labels
# Out:
# ['Close', 'volume_obv', 'others_dr', 'others_dlr', 'others_cr']

# %%
y_pred_proba = classifier.predict_proba(X_test)
y_pred_proba
# Out:
# array([[0.74655789, 0.25344211],
#        [0.81617267, 0.18382733],
#        [0.83461494, 0.16538506],
#        ...,
#        [0.35952933, 0.64047067],
#        [0.30016286, 0.69983714],
#        [0.63019708, 0.36980292]])

# %%
# Test for Overfitting
train_scores, test_scores = list(), list()
y_test_probality =[]
values = [i for i in range(1, 200)]
for i in values:
    classifier = {}
    classifier = RandomForestClassifier(n_estimators=i, max_depth=2, random_state=0)
   
    #with open('./TrainedModel/indicator/{}_model_2.pkl'.format(stock_name), 'rb') as f:
     #   classifier = pickle.load(f)
        
    classifier.fit(X_train, y_train)
    
    # Training Data
    y_train_pred = classifier.predict(X_train)
    accuracy_train = accuracy_score(y_train, y_train_pred)
    train_scores.append(accuracy_train)
    
    # Test Data
    y_test_pred = classifier.predict(X_test)
    y_test_probality = classifier.predict_proba(X_test)

    accuracy_test = accuracy_score(y_test, y_test_pred)
    test_scores.append(accuracy_test)

# %%
accuracy_test
# Out:
# 0.7374631268436578

# %%
data_analysis = {
    "real" :        y_test,
    "predication" : y_test_pred,
    "probality_one" :   y_test_probality[:,0],
    "probality_two" :   y_test_probality[:,1]

}
df_d = pd.DataFrame(data_analysis)

# %%
failData = df_d[df_d["real"] != df_d["predication"]]
sucessData = df_d[df_d["real"] == df_d["predication"]]
print("fail records :",len(failData),"success reacords :",len(sucessData))
# Out:
# fail records : 712 success reacords : 2000

# %%
biggest_num = []
for i in range(0,len(failData)):
        if failData.iloc[i].probality_one > failData.iloc[i].probality_two:
            biggest_num.append(failData.iloc[i].probality_one)
        else:
             biggest_num.append(failData.iloc[i].probality_two)

# %%
probalityFilterd = failData[failData["biggest_num"] > 0.58]
print("Total Erro len :",len(failData),"Filter error :",len(probalityFilterd))
probalityFilterd.head(50)
#failData
# Out:
# Total Erro len : 712 Filter error : 553
#             real  predication  probality_one  probality_two  biggest_num
# Date
# 2009-01-19     1           -1       0.735213       0.264787     0.735213
# 2016-04-08     1           -1       0.613792       0.386208     0.613792
# 2013-04-12     1           -1       0.660309       0.339691     0.660309
# 2021-05-06     1           -1       0.611936       0.388064     0.611936
# 2014-10-17     1           -1       0.792367       0.207633     0.792367
# 2018-12-26    -1            1       0.391075       0.608925     0.608925
# 2021-07-23    -1            1       0.327116       0.672884     0.672884
# 2019-10-25     1           -1       0.622938       0.377062     0.622938
# 2017-01-11     1           -1       0.678176       0.321824     0.678176
# 2014-11-05     1           -1       0.779204       0.220796     0.779204
# 2020-09-17    -1            1       0.258175       0.741825     0.741825
# 2022-09-21    -1            1       0.282967       0.717033     0.717033
# 2017-05-18    -1            1       0.276860       0.723140     0.723140
# 2013-06-27     1           -1       0.679980       0.320020     0.679980
# 2009-05-20     1           -1       0.817004       0.182996     0.817004
# 2011-03-24     1           -1       0.762920       0.237080     0.762920
# 2021-06-23    -1            1       0.314092       0.685908     0.685908
# 2012-08-01    -1            1       0.291496       0.708504     0.708504
# 2021-10-06     1           -1       0.582156       0.417844     0.582156
# 2020-12-17    -1            1       0.280425       0.719575     0.719575
# 2019-07-05    -1            1       0.187449       0.812551     0.812551
# 2020-01-31    -1            1       0.191129       0.808871     0.808871
# 2012-03-27    -1            1       0.312280       0.687720     0.687720
# 2020-02-26    -1            1       0.192717       0.807283     0.807283
# 2008-07-04     1           -1       0.650302       0.349698     0.650302
# 2012-07-23    -1            1       0.410969       0.589031     0.589031
# 2014-06-09    -1            1       0.232354       0.767646     0.767646
# 2014-03-26     1           -1       0.653720       0.346280     0.653720
# 2018-04-06     1           -1       0.610089       0.389911     0.610089
# 2008-02-01     1           -1       0.866741       0.133259     0.866741
# 2011-02-17    -1            1       0.303018       0.696982     0.696982
# 2018-04-18    -1            1       0.234597       0.765403     0.765403
# 2023-07-10    -1            1       0.217487       0.782513     0.782513
# 2012-07-10     1           -1       0.587978       0.412022     0.587978
# 2008-03-12    -1            1       0.218046       0.781954     0.781954
# 2012-07-05     1           -1       0.609844       0.390156     0.609844
# 2012-04-16     1           -1       0.580588       0.419412     0.580588
# 2022-03-31     1           -1       0.756077       0.243923     0.756077
# 2021-06-17    -1            1       0.247477       0.752523     0.752523
# 2019-02-04    -1            1       0.283991       0.716009     0.716009
# 2009-06-01    -1            1       0.259562       0.740438     0.740438
# 2015-04-01     1           -1       0.643369       0.356631     0.643369
# 2008-02-25     1           -1       0.816503       0.183497     0.816503
# 2020-07-29    -1            1       0.296120       0.703880     0.703880
# 2015-07-30    -1            1       0.338444       0.661556     0.661556
# 2007-12-03     1           -1       0.840091       0.159909     0.840091
# 2017-11-15     1           -1       0.645421       0.354579     0.645421
# 2016-05-23    -1            1       0.230195       0.769805     0.769805
# 2018-05-24     1           -1       0.768355       0.231645     0.768355
# 2008-05-09    -1            1       0.236805       0.763195     0.763195

# %%
# Plot Results
plt.plot(train_scores)
plt.plot(test_scores)
plt.show()

# %% [markdown]
# ### Conclusion

# %% [markdown]
# We have seen that by introducing PCA, we can dramatically reduce the amount of data required to train our supervised machine learning model (in this case Random Forest). One could further explore information provided by PCA by running K-Means clusters on the PCA data to find certain regimes in the data.
#
# This is the fun part about machine learning, there are many ways to combine methods in the aim to optimize your strategy.

# %% [markdown]
# ### Useful Resources and Reading

# %% [markdown]
# Use Case in Correlation for Stock Analysis: https://python.plainenglish.io/applying-pca-to-stocks-fbad2e51573f
#
# Understanding the VIX: https://www.investopedia.com/stock-analysis/2012/4-ways-to-trade-the-vix-vxx-vxz-tvix-xxv0504.aspx
#
# Using PCA in Forex Trading:
# https://deanstreetlab.github.io/papers/papers/FX%20Trading/Using%20a%20Principal%20Component%20Analysis%20for%20Multi-Currencies-Trading%20in%20the%20Foreign%20Exchange%20Market.pdf
