# %% [markdown]
# #Libraries and Data

# %%
#import libraries
import numpy as np
import pandas as pd
import itertools
from prophet import Prophet
import yfinance
import pickle
from ta import add_all_ta_features
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from statsmodels.tsa.stattools import adfuller
from matplotlib.pylab import rcParams
from sklearn import tree

# %%
#load the data

data = yfinance.download (tickers = "TATAPOWER.NS",start="2017-03-06",
                               interval = "1d", group_by = 'ticker', auto_adjust = True)

data.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close    Volume
# Date
# 2023-07-07  229.800003  232.350006  226.100006  228.000000  16592198
# 2023-07-10  229.250000  229.250000  224.649994  225.000000   7143637
# 2023-07-11  226.000000  226.850006  224.699997  225.500000   5156417
# 2023-07-12  226.250000  227.250000  225.199997  226.300003   7366992
# 2023-07-13  227.000000  227.199997  220.899994  222.149994   9362010

# %% [markdown]
# #Data preparation

# %%
#transform the date variable
data["Date"] = pd.to_datetime(data.index, format = "%m/%d/%Y")

# %%
#renaming variables
data["y"] = data["Close"]
data = data.rename(columns = {
                     'Date': 'ds'})
data.head(10)
data = data.reset_index()

# %% [markdown]
# #Holidays

# %%
#Easter
#easter_dates = df[df.Easter == 1].ds
#easter = pd.DataFrame({'holiday': 'easter',
#                      'ds': pd.to_datetime(easter_dates),
#                      'lower_window': -5,
#                      'upper_window': 2})
#easter.head(2)

# %%
#Thanksgiving
#thanksgiving_dates = df[df.Thanksgiving == 1].ds
#thanksgiving = pd.DataFrame({'holiday': 'thanksgiving',
 #                      'ds': pd.to_datetime(thanksgiving_dates),
  #                     'lower_window': -5,
   #                    'upper_window': 2})
#thanksgiving.head(2)

# %%
#combining holidays
#holidays = pd.concat([easter, thanksgiving])
#holidays

# %%
data  = add_all_ta_features(data, open="Open", high="High", low="Low", close="Close", volume="Volume", fillna=True)
# Out:
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/trend.py:780: RuntimeWarning: invalid value encountered in scalar divide
#   dip[idx] = 100 * (self._dip[idx] / value)
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/trend.py:785: RuntimeWarning: invalid value encountered in scalar divide
#   din[idx] = 100 * (self._din[idx] / value)

# %%
#create training and test set
test_days = 360
training_set = data.iloc[:-test_days,:]
test_set = data.iloc[-test_days:,:]

# %%
training_set
# Out:
#            Date        Open        High         Low       Close    Volume  \
# 0    2017-03-06   68.984702   69.615659   68.900575   69.363274   4706563
# 1    2017-03-07   69.741839   70.456923   69.573580   69.825966   7309780
# 2    2017-03-08   70.036294   70.120421   68.942632   69.068825   3008752
# 3    2017-03-09   68.984686   69.531517   68.564048   69.152939   4968194
# 4    2017-03-10   69.237079   69.994223   68.395802   68.942627   1925931
# ...         ...         ...         ...         ...         ...       ...
# 1207 2022-01-21  241.598281  246.512810  234.472213  237.814087  35507032
# 1208 2022-01-24  238.354697  239.681626  222.726499  225.626068  43279408
# 1209 2022-01-25  222.382469  236.732901  219.188024  234.717941  39449718
# 1210 2022-01-27  231.474343  238.207255  228.525625  236.929474  35920383
# 1211 2022-01-28  240.517072  245.726476  238.698705  239.878189  34523855
#
#              ds           y    volume_adi  volume_obv  ...  momentum_ppo  \
# 0    2017-03-06   69.363274  1.384243e+06     4706563  ...      0.000000
# 1    2017-03-07   69.825966 -1.748489e+06    12016343  ...      0.053186
# 2    2017-03-08   69.068825 -4.112503e+06     9007591  ...      0.007220
# 3    2017-03-09   69.152939 -3.032495e+06    13975785  ...     -0.019223
# 4    2017-03-10   68.942627 -3.640692e+06    12049854  ...     -0.063940
# ...         ...         ...           ...         ...  ...           ...
# 1207 2022-01-21  237.814087  1.110350e+08  4564387284  ...      2.650096
# 1208 2022-01-24  225.626068  8.255839e+07  4521107876  ...      2.107775
# 1209 2022-01-25  234.717941  1.129468e+08  4560557594  ...      1.969074
# 1210 2022-01-27  236.929474  1.393857e+08  4596477977  ...      1.913199
# 1211 2022-01-28  239.878189  1.164502e+08  4631001832  ...      1.947338
#
#       momentum_ppo_signal  momentum_ppo_hist  momentum_pvo  \
# 0                0.000000           0.000000      0.000000
# 1                0.010637           0.042549      4.238566
# 2                0.009954          -0.002734      0.523082
# 3                0.004118          -0.023341      0.790092
# 4               -0.009493          -0.054447     -4.280216
# ...                   ...                ...           ...
# 1207             2.031511           0.618585     -2.511247
# 1208             2.046763           0.061011      0.281809
# 1209             2.031226          -0.062152      1.506523
# 1210             2.007620          -0.094421      1.627137
# 1211             1.995564          -0.048226      1.383929
#
#       momentum_pvo_signal  momentum_pvo_hist  momentum_kama  others_dr  \
# 0                0.000000           0.000000      69.363274 -37.731092
# 1                0.847713           3.390853      69.566075   0.667057
# 2                0.782787          -0.259705      69.351318  -1.084326
# 3                0.784248           0.005844      69.264738   0.121783
# 4               -0.228645          -4.051571      69.110726  -0.304126
# ...                   ...                ...            ...        ...
# 1207            -9.474715           6.963468     238.362980  -2.694555
# 1208            -7.523411           7.805220     238.263286  -5.125020
# 1209            -5.717424           7.223947     238.213228   4.029620
# 1210            -4.248512           5.875649     238.201100   0.942209
# 1211            -3.122024           4.505953     238.211277   1.244554
#
#       others_dlr   others_cr
# 0       0.000000    0.000000
# 1       0.664842    0.667057
# 2      -1.090248   -0.424503
# 3       0.121709   -0.303237
# 4      -0.304589   -0.606440
# ...          ...         ...
# 1207   -2.731523  242.853032
# 1208   -5.261016  225.281747
# 1209    3.950548  238.389365
# 1210    0.937797  241.577699
# 1211    1.236873  245.828818
#
# [1212 rows x 94 columns]

# %% [markdown]
# #Prophet

# %%
m = Prophet(
            #holidays = holidays,
            #seasonality_mode = 'multiplicative',
            #seasonality_prior_scale = 20,
           # changepoint_prior_scale = 0.1,
           # holidays_prior_scale = 10
           )
m.add_regressor('volume_adi')
m.add_regressor('volume_obv')
m.add_regressor('volume_cmf')
m.add_regressor('others_dr')
m.add_regressor('volume_adi')
m.fit(training_set)
# Out:
# 16:00:16 - cmdstanpy - INFO - Chain [1] start processing
# 16:00:17 - cmdstanpy - INFO - Chain [1] done processing

# %%
#create future df
#future = m.make_future_dataframe(periods = test_days,
 #                                freq = "D")

# %%
future = pd.DataFrame({"ds" : data.ds})

# %%
#forecast
forecast = m.predict(data)
forecast.tail()
# Out:
#              ds       trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 1567 2023-07-07  119.571828  189.646703  431.612094    -4.946987   237.792175
# 1568 2023-07-10  119.962927  189.171972  433.301701    -4.852364   238.756769
# 1569 2023-07-11  120.093294  189.415466  433.916098    -4.959604   239.452837
# 1570 2023-07-12  120.223660  188.856017  433.536663    -5.066843   240.120650
# 1571 2023-07-13  120.354027  188.095084  433.052166    -5.174083   240.569173
#
#       additive_terms  additive_terms_lower  additive_terms_upper  \
# 1567      193.534632            193.534632            193.534632
# 1568      192.990301            192.990301            192.990301
# 1569      193.531143            193.531143            193.531143
# 1570      194.098283            194.098283            194.098283
# 1571      192.777447            192.777447            192.777447
#
#       extra_regressors_additive  ...    weekly  weekly_lower  weekly_upper  \
# 1567                 205.444107  ... -0.259086     -0.259086     -0.259086
# 1568                 204.779111  ... -0.169430     -0.169430     -0.169430
# 1569                 205.300531  ... -0.184206     -0.184206     -0.184206
# 1570                 205.702812  ... -0.066951     -0.066951     -0.066951
# 1571                 204.406526  ... -0.153109     -0.153109     -0.153109
#
#          yearly  yearly_lower  yearly_upper  multiplicative_terms  \
# 1567 -11.650390    -11.650390    -11.650390                   0.0
# 1568 -11.619379    -11.619379    -11.619379                   0.0
# 1569 -11.585182    -11.585182    -11.585182                   0.0
# 1570 -11.537578    -11.537578    -11.537578                   0.0
# 1571 -11.475970    -11.475970    -11.475970                   0.0
#
#       multiplicative_terms_lower  multiplicative_terms_upper        yhat
# 1567                         0.0                         0.0  313.106459
# 1568                         0.0                         0.0  312.953228
# 1569                         0.0                         0.0  313.624437
# 1570                         0.0                         0.0  314.321943
# 1571                         0.0                         0.0  313.131474
#
# [5 rows x 34 columns]

# %%
data = data.reset_index(level=None, drop=False, inplace=False, col_level=0, col_fill='')
data = data.drop("index",axis=1)

# %%
#get some variables
prophet_variables = forecast.loc[:, ["trend", "weekly",  "multiplicative_terms","trend_upper","trend_lower"]]
df_xgb = pd.concat([data, prophet_variables], axis = 1)
df_xgb.head(1)
# Out:
#         Date       Open       High        Low      Close   Volume         ds  \
# 0 2017-03-06  68.984702  69.615659  68.900575  69.363274  4706563 2017-03-06
#
#            y    volume_adi  volume_obv  ...  momentum_pvo_hist  momentum_kama  \
# 0  69.363274  1.384243e+06     4706563  ...                0.0      69.363274
#
#    others_dr  others_dlr  others_cr       trend   weekly  \
# 0 -37.731092         0.0        0.0  111.563533 -0.16943
#
#    multiplicative_terms  trend_upper  trend_lower
# 0                   0.0   111.563533   111.563533
#
# [1 rows x 99 columns]

# %%
df_xgb  = add_all_ta_features(df_xgb, open="Open", high="High", low="Low", close="Close", volume="Volume", fillna=True)
# Out:
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/trend.py:780: RuntimeWarning: invalid value encountered in scalar divide
#   dip[idx] = 100 * (self._dip[idx] / value)
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/ta/trend.py:785: RuntimeWarning: invalid value encountered in scalar divide
#   din[idx] = 100 * (self._din[idx] / value)

# %%
    
non_stationaries = []
for col in df_xgb.columns:
    if col != "multiplicative_terms" and col != "Date" and col != "ds" :
        print(col)
        dftest = adfuller(df_xgb[col].values)
        p_value = dftest[1]
        t_test = dftest[0] < dftest[4]["1%"]
        if p_value > 0.05 or not t_test:
            non_stationaries.append(col)
print(f"Non-Stationary Features Found: {len(non_stationaries)}")
# Out:
# Open
# High
# Low
# Close
# Volume
# y
# volume_adi
# volume_obv
# volume_cmf
# volume_fi
# volume_em
# volume_sma_em
# volume_vpt
# volume_vwap
# volume_mfi
# volume_nvi
# volatility_bbm
# volatility_bbh
# volatility_bbl
# volatility_bbw
# volatility_bbp
# volatility_bbhi
# volatility_bbli
# volatility_kcc
# volatility_kch
# volatility_kcl
# volatility_kcw
# volatility_kcp
# volatility_kchi
# volatility_kcli
# volatility_dcl
# volatility_dch
# volatility_dcm
# volatility_dcw
# volatility_dcp
# volatility_atr
# volatility_ui
# trend_macd
# trend_macd_signal
# trend_macd_diff
# trend_sma_fast
# trend_sma_slow
# trend_ema_fast
# trend_ema_slow
# trend_vortex_ind_pos
# trend_vortex_ind_neg
# trend_vortex_ind_diff
# trend_trix
# trend_mass_index
# trend_dpo
# trend_kst
# trend_kst_sig
# trend_kst_diff
# trend_ichimoku_conv
# trend_ichimoku_base
# trend_ichimoku_a
# trend_ichimoku_b
# trend_stc
# trend_adx
# trend_adx_pos
# trend_adx_neg
# trend_cci
# trend_visual_ichimoku_a
# trend_visual_ichimoku_b
# trend_aroon_up
# trend_aroon_down
# trend_aroon_ind
# trend_psar_up
# trend_psar_down
# trend_psar_up_indicator
# trend_psar_down_indicator
# momentum_rsi
# momentum_stoch_rsi
# momentum_stoch_rsi_k
# momentum_stoch_rsi_d
# momentum_tsi
# momentum_uo
# momentum_stoch
# momentum_stoch_signal
# momentum_wr
# momentum_ao
# momentum_roc
# momentum_ppo
# momentum_ppo_signal
# momentum_ppo_hist
# momentum_pvo
# momentum_pvo_signal
# momentum_pvo_hist
# momentum_kama
# others_dr
# others_dlr
# others_cr
# trend
# weekly
# trend_upper
# trend_lower
# Non-Stationary Features Found: 35

# %%
df_stationary = df_xgb.copy()

df_stationary = df_stationary.drop(columns=["Date","ds"])
df_stationary
# Out:
#             Open        High         Low       Close    Volume           y  \
# 0      68.984702   69.615659   68.900575   69.363274   4706563   69.363274
# 1      69.741839   70.456923   69.573580   69.825966   7309780   69.825966
# 2      70.036294   70.120421   68.942632   69.068825   3008752   69.068825
# 3      68.984686   69.531517   68.564048   69.152939   4968194   69.152939
# 4      69.237079   69.994223   68.395802   68.942627   1925931   68.942627
# ...          ...         ...         ...         ...       ...         ...
# 1567  229.800003  232.350006  226.100006  228.000000  16592198  228.000000
# 1568  229.250000  229.250000  224.649994  225.000000   7143637  225.000000
# 1569  226.000000  226.850006  224.699997  225.500000   5156417  225.500000
# 1570  226.250000  227.250000  225.199997  226.300003   7366992  226.300003
# 1571  227.000000  227.199997  220.899994  222.149994   9362010  222.149994
#
#         volume_adi  volume_obv  volume_cmf     volume_fi  ...  \
# 0     1.384243e+06     4706563    0.294109  0.000000e+00  ...
# 1    -1.748489e+06    12016343   -0.145509  3.382179e+06  ...
# 2    -4.112503e+06     9007591   -0.273709  2.573575e+06  ...
# 3    -3.032495e+06    13975785   -0.151676  2.265620e+06  ...
# 4    -3.640692e+06    12049854   -0.166096  1.884097e+06  ...
# ...            ...         ...         ...           ...  ...
# 1567 -2.037085e+08  5480198866    0.013058  2.791326e+07  ...
# 1568 -2.097650e+08  5473055229    0.013168  2.086409e+07  ...
# 1569 -2.110841e+08  5478211646    0.028744  1.825182e+07  ...
# 1570 -2.105450e+08  5485578638    0.032625  1.648636e+07  ...
# 1571 -2.161919e+08  5476216628   -0.025169  8.580821e+06  ...
#
#       momentum_pvo_hist  momentum_kama  others_dr  others_dlr   others_cr  \
# 0              0.000000      69.363274 -37.731092    0.000000    0.000000
# 1              3.390853      69.566075   0.667057    0.664842    0.667057
# 2             -0.259705      69.351318  -1.084326   -1.090248   -0.424503
# 3              0.005844      69.264738   0.121783    0.121709   -0.303237
# 4             -4.051571      69.110726  -0.304126   -0.304589   -0.606440
# ...                 ...            ...        ...         ...         ...
# 1567          15.857850     221.131214  -0.696867   -0.699306  228.704209
# 1568           9.356324     221.442765  -1.315789   -1.324523  224.379154
# 1569           3.420902     221.779041   0.222222    0.221976  225.099996
# 1570           0.831191     222.161683   0.354769    0.354141  226.253349
# 1571           0.486863     222.161451  -1.833853   -1.850876  220.270342
#
#            trend    weekly  multiplicative_terms  trend_upper  trend_lower
# 0     111.563533 -0.169430                   0.0   111.563533   111.563533
# 1     111.649041 -0.184206                   0.0   111.649041   111.649041
# 2     111.734548 -0.066951                   0.0   111.734548   111.734548
# 3     111.820056 -0.153109                   0.0   111.820056   111.820056
# 4     111.905564 -0.259086                   0.0   111.905564   111.905564
# ...          ...       ...                   ...          ...          ...
# 1567  119.571828 -0.259086                   0.0   237.792175    -4.946987
# 1568  119.962927 -0.169430                   0.0   238.756769    -4.852364
# 1569  120.093294 -0.184206                   0.0   239.452837    -4.959604
# 1570  120.223660 -0.066951                   0.0   240.120650    -5.066843
# 1571  120.354027 -0.153109                   0.0   240.569173    -5.174083
#
# [1572 rows x 97 columns]

# %%
df_stationary[non_stationaries] = df_stationary[non_stationaries].pct_change()

# %% [markdown]
# #XGBoost preparation

# %%
#create training and test set
test_days = 360
training_set = df_xgb.iloc[:-test_days,:]
test_set = df_xgb.iloc[-test_days:,:]

# %%
#isolate X and y
y_train = training_set.y
y_test = test_set.y 

X_train = training_set.iloc[:, 2:]

X_test = test_set.iloc[:, 2:]

# %%
X_test
# Out:
#             High         Low       Close    Volume         ds           y  \
# 1212  245.284180  241.106830  241.844009  24939671 2022-01-31  241.844009
# 1213  252.017078  240.615378  245.579056  74185275 2022-02-01  245.579056
# 1214  250.641019  244.989309  246.316238  25162901 2022-02-02  246.316238
# 1215  250.051263  245.038452  248.527771  27724870 2022-02-03  248.527771
# 1216  253.491440  248.675207  250.002136  39309420 2022-02-04  250.002136
# ...          ...         ...         ...       ...        ...         ...
# 1567  232.350006  226.100006  228.000000  16592198 2023-07-07  228.000000
# 1568  229.250000  224.649994  225.000000   7143637 2023-07-10  225.000000
# 1569  226.850006  224.699997  225.500000   5156417 2023-07-11  225.500000
# 1570  227.250000  225.199997  226.300003   7366992 2023-07-12  226.300003
# 1571  227.199997  220.899994  222.149994   9362010 2023-07-13  222.149994
#
#         volume_adi  volume_obv  volume_cmf     volume_fi  ...  \
# 1212  1.003128e+08  4655941503    0.066551  2.884054e+07  ...
# 1213  9.071994e+07  4730126778    0.023549  6.430410e+07  ...
# 1214  7.737272e+07  4755289679   -0.017392  5.776775e+07  ...
# 1215  8.824532e+07  4783014549    0.016184  5.827442e+07  ...
# 1216  7.059632e+07  4822323969   -0.037522  5.822899e+07  ...
# ...            ...         ...         ...           ...  ...
# 1567 -2.037085e+08  5480198866    0.013058  2.791326e+07  ...
# 1568 -2.097650e+08  5473055229    0.013168  2.086409e+07  ...
# 1569 -2.110841e+08  5478211646    0.028744  1.825182e+07  ...
# 1570 -2.105450e+08  5485578638    0.032625  1.648636e+07  ...
# 1571 -2.161919e+08  5476216628   -0.025169  8.580821e+06  ...
#
#       momentum_pvo_hist  momentum_kama  others_dr  others_dlr   others_cr  \
# 1212           1.649239     238.235608   0.819508    0.816168  248.662912
# 1213           8.517939     238.289150   1.544403    1.532599  254.047672
# 1214           3.902178     238.622704   0.300181    0.299732  255.110458
# 1215           1.161922     238.780145   0.897843    0.893836  258.298791
# 1216           1.408124     239.008661   0.593240    0.591487  260.424362
# ...                 ...            ...        ...         ...         ...
# 1567          15.857850     221.131214  -0.696867   -0.699306  228.704209
# 1568           9.356324     221.442765  -1.315789   -1.324523  224.379154
# 1569           3.420902     221.779041   0.222222    0.221976  225.099996
# 1570           0.831191     222.161683   0.354769    0.354141  226.253349
# 1571           0.486863     222.161451  -1.833853   -1.850876  220.270342
#
#            trend    weekly  multiplicative_terms  trend_upper  trend_lower
# 1212   51.520508 -0.169430                   0.0    51.520508    51.520508
# 1213   51.650874 -0.184206                   0.0    51.650874    51.650874
# 1214   51.781241 -0.066951                   0.0    51.781241    51.781241
# 1215   51.911607 -0.153109                   0.0    51.911607    51.911607
# 1216   52.041974 -0.259086                   0.0    52.041974    52.041974
# ...          ...       ...                   ...          ...          ...
# 1567  119.571828 -0.259086                   0.0   237.792175    -4.946987
# 1568  119.962927 -0.169430                   0.0   238.756769    -4.852364
# 1569  120.093294 -0.184206                   0.0   239.452837    -4.959604
# 1570  120.223660 -0.066951                   0.0   240.120650    -5.066843
# 1571  120.354027 -0.153109                   0.0   240.569173    -5.174083
#
# [360 rows x 97 columns]

# %%
X_train = X_train.drop(columns=["ds"])
X_test = X_test.drop(columns=["ds"])
#X_test = StandardScaler().fit_transform(X_test)
#X_train = StandardScaler().fit_transform(X_train)
#y_train = StandardScaler().fit_transform(y_train)
#y_test = StandardScaler().fit_transform(y_test)

# %%
#Matrices
import xgboost as xgb
Train = xgb.DMatrix(X_train, label = y_train)
Test = xgb.DMatrix(X_test, label = y_test)

# %%
X_train
# Out:
#             High         Low       Close    Volume           y    volume_adi  \
# 0      69.615659   68.900575   69.363274   4706563   69.363274  1.384243e+06
# 1      70.456923   69.573580   69.825966   7309780   69.825966 -1.748489e+06
# 2      70.120421   68.942632   69.068825   3008752   69.068825 -4.112503e+06
# 3      69.531517   68.564048   69.152939   4968194   69.152939 -3.032495e+06
# 4      69.994223   68.395802   68.942627   1925931   68.942627 -3.640692e+06
# ...          ...         ...         ...       ...         ...           ...
# 1207  246.512810  234.472213  237.814087  35507032  237.814087  1.110350e+08
# 1208  239.681626  222.726499  225.626068  43279408  225.626068  8.255839e+07
# 1209  236.732901  219.188024  234.717941  39449718  234.717941  1.129468e+08
# 1210  238.207255  228.525625  236.929474  35920383  236.929474  1.393857e+08
# 1211  245.726476  238.698705  239.878189  34523855  239.878189  1.164502e+08
#
#       volume_obv  volume_cmf     volume_fi   volume_em  ...  \
# 0        4706563    0.294109  0.000000e+00    0.000000  ...
# 1       12016343   -0.145509  3.382179e+06    9.149518  ...
# 2        9007591   -0.273709  2.573575e+06  -18.935641  ...
# 3       13975785   -0.151676  2.265620e+06   -9.420072  ...
# 4       12049854   -0.166096  1.884097e+06   12.219316  ...
# ...          ...         ...           ...         ...  ...
# 1207  4564387284    0.127771  2.040738e+07 -132.490032  ...
# 1208  4521107876    0.048944 -5.786371e+07 -363.884004  ...
# 1209  4560557594    0.077093  1.641372e+06 -144.255923  ...
# 1210  4596477977    0.135208  1.275533e+07  145.707425  ...
# 1211  4631001832    0.102139  2.547614e+07  180.074685  ...
#
#       momentum_pvo_hist  momentum_kama  others_dr  others_dlr   others_cr  \
# 0              0.000000      69.363274 -37.731092    0.000000    0.000000
# 1              3.390853      69.566075   0.667057    0.664842    0.667057
# 2             -0.259705      69.351318  -1.084326   -1.090248   -0.424503
# 3              0.005844      69.264738   0.121783    0.121709   -0.303237
# 4             -4.051571      69.110726  -0.304126   -0.304589   -0.606440
# ...                 ...            ...        ...         ...         ...
# 1207           6.963468     238.362980  -2.694555   -2.731523  242.853032
# 1208           7.805220     238.263286  -5.125020   -5.261016  225.281747
# 1209           7.223947     238.213228   4.029620    3.950548  238.389365
# 1210           5.875649     238.201100   0.942209    0.937797  241.577699
# 1211           4.505953     238.211277   1.244554    1.236873  245.828818
#
#            trend    weekly  multiplicative_terms  trend_upper  trend_lower
# 0     111.563533 -0.169430                   0.0   111.563533   111.563533
# 1     111.649041 -0.184206                   0.0   111.649041   111.649041
# 2     111.734548 -0.066951                   0.0   111.734548   111.734548
# 3     111.820056 -0.153109                   0.0   111.820056   111.820056
# 4     111.905564 -0.259086                   0.0   111.905564   111.905564
# ...          ...       ...                   ...          ...          ...
# 1207   50.216842 -0.259086                   0.0    50.216842    50.216842
# 1208   50.607942 -0.169430                   0.0    50.607942    50.607942
# 1209   50.738308 -0.184206                   0.0    50.738308    50.738308
# 1210   50.999041 -0.153109                   0.0    50.999041    50.999041
# 1211   51.129408 -0.259086                   0.0    51.129408    51.129408
#
# [1212 rows x 96 columns]

# %%
#set the parameters
parameters = {
              'learning_rate': 0.1,
              'max_depth': 40,
              'colsample_bytree': 1,
              'subsample': 1,
              'min_child_weight' : 1,
              'gamma': 0,
              'random_state': 1600,
              'eval_metric': "rmse",
              'objective': "reg:squarederror"}

# %% [markdown]
# #XGBoost

# %%
model = xgb.train(params = parameters,
                  dtrain = Train,
                  num_boost_round = 160,
                  evals = [(Test, "y")])
# Out:
# [0]	y-rmse:197.42465
# [1]	y-rmse:177.92727
# [2]	y-rmse:159.93859
# [3]	y-rmse:144.03721
# [4]	y-rmse:129.45249
# [5]	y-rmse:116.56235
# [6]	y-rmse:104.74347
# [7]	y-rmse:94.12040
# [8]	y-rmse:85.20479
# [9]	y-rmse:77.29499
# [10]	y-rmse:69.58606
# [11]	y-rmse:63.22840
# [12]	y-rmse:57.41655
# [13]	y-rmse:51.84774
# [14]	y-rmse:46.89918
# [15]	y-rmse:42.48699
# [16]	y-rmse:38.58817
# [17]	y-rmse:34.97878
# [18]	y-rmse:31.78326
# [19]	y-rmse:28.94275
# [20]	y-rmse:26.38230
# [21]	y-rmse:24.15321
# [22]	y-rmse:22.00257
# [23]	y-rmse:20.07230
# [24]	y-rmse:18.36912
# [25]	y-rmse:16.85365
# [26]	y-rmse:15.48896
# [27]	y-rmse:14.24856
# [28]	y-rmse:13.13805
# [29]	y-rmse:12.15856
# [30]	y-rmse:11.31840
# [31]	y-rmse:10.52446
# [32]	y-rmse:9.82235
# [33]	y-rmse:9.22049
# [34]	y-rmse:8.67835
# [35]	y-rmse:8.16678
# [36]	y-rmse:7.72294
# [37]	y-rmse:7.32724
# [38]	y-rmse:6.98624
# [39]	y-rmse:6.68850
# [40]	y-rmse:6.45502
# [41]	y-rmse:6.24878
# [42]	y-rmse:6.03754
# [43]	y-rmse:5.87755
# [44]	y-rmse:5.71963
# [45]	y-rmse:5.59179
# [46]	y-rmse:5.46821
# [47]	y-rmse:5.34845
# [48]	y-rmse:5.24150
# [49]	y-rmse:5.14916
# [50]	y-rmse:5.04793
# [51]	y-rmse:4.95995
# [52]	y-rmse:4.87594
# [53]	y-rmse:4.79824
# [54]	y-rmse:4.72876
# [55]	y-rmse:4.66033
# [56]	y-rmse:4.59986
# [57]	y-rmse:4.54160
# [58]	y-rmse:4.48920
# [59]	y-rmse:4.43978
# [60]	y-rmse:4.39249
# [61]	y-rmse:4.35015
# [62]	y-rmse:4.30970
# [63]	y-rmse:4.27235
# [64]	y-rmse:4.23769
# [65]	y-rmse:4.20453
# [66]	y-rmse:4.17369
# [67]	y-rmse:4.14472
# [68]	y-rmse:4.11737
# [69]	y-rmse:4.09162
# [70]	y-rmse:4.06517
# [71]	y-rmse:4.04025
# [72]	y-rmse:4.01776
# [73]	y-rmse:3.99749
# [74]	y-rmse:3.97737
# [75]	y-rmse:3.95866
# [76]	y-rmse:3.94108
# [77]	y-rmse:3.92455
# [78]	y-rmse:3.90886
# [79]	y-rmse:3.89340
# [80]	y-rmse:3.87949
# [81]	y-rmse:3.86612
# [82]	y-rmse:3.85375
# [83]	y-rmse:3.84208
# [84]	y-rmse:3.83027
# [85]	y-rmse:3.81916
# [86]	y-rmse:3.80882
# [87]	y-rmse:3.79898
# [88]	y-rmse:3.78953
# [89]	y-rmse:3.78075
# [90]	y-rmse:3.77231
# [91]	y-rmse:3.76432
# [92]	y-rmse:3.75680
# [93]	y-rmse:3.74995
# [94]	y-rmse:3.74347
# [95]	y-rmse:3.73726
# [96]	y-rmse:3.73137
# [97]	y-rmse:3.72579
# [98]	y-rmse:3.72052
# [99]	y-rmse:3.71537
# [100]	y-rmse:3.71063
# [101]	y-rmse:3.70614
# [102]	y-rmse:3.70188
# [103]	y-rmse:3.69789
# [104]	y-rmse:3.69407
# [105]	y-rmse:3.69044
# [106]	y-rmse:3.68699
# [107]	y-rmse:3.68372
# [108]	y-rmse:3.68062
# [109]	y-rmse:3.67768
# [110]	y-rmse:3.67490
# [111]	y-rmse:3.67226
# [112]	y-rmse:3.66970
# [113]	y-rmse:3.66729
# [114]	y-rmse:3.66499
# [115]	y-rmse:3.66282
# [116]	y-rmse:3.66073
# [117]	y-rmse:3.65874
# [118]	y-rmse:3.65686
# [119]	y-rmse:3.65507
# [120]	y-rmse:3.65344
# [121]	y-rmse:3.65190
# [122]	y-rmse:3.65038
# [123]	y-rmse:3.64892
# [124]	y-rmse:3.64756
# [125]	y-rmse:3.64625
# [126]	y-rmse:3.64502
# [127]	y-rmse:3.64387
# [128]	y-rmse:3.64278
# [129]	y-rmse:3.64174
# [130]	y-rmse:3.64076
# [131]	y-rmse:3.63983
# [132]	y-rmse:3.63894
# [133]	y-rmse:3.63810
# [134]	y-rmse:3.63730
# [135]	y-rmse:3.63654
# [136]	y-rmse:3.63581
# [137]	y-rmse:3.63513
# [138]	y-rmse:3.63447
# [139]	y-rmse:3.63385
# [140]	y-rmse:3.63326
# [141]	y-rmse:3.63271
# [142]	y-rmse:3.63217
# [143]	y-rmse:3.63167
# [144]	y-rmse:3.63120
# [145]	y-rmse:3.63076
# [146]	y-rmse:3.63034
# [147]	y-rmse:3.62995
# [148]	y-rmse:3.62957
# [149]	y-rmse:3.62921
# [150]	y-rmse:3.62887
# [151]	y-rmse:3.62855
# [152]	y-rmse:3.62825
# [153]	y-rmse:3.62795
# [154]	y-rmse:3.62768
# [155]	y-rmse:3.62742
# [156]	y-rmse:3.62717
# [157]	y-rmse:3.62692
# [158]	y-rmse:3.62669
# [159]	y-rmse:3.62648

# %%
dir(model)
print(model.get_score())
# Out:
# {'High': 1857.0, 'Low': 636.0, 'Close': 1244.0, 'Volume': 1255.0, 'volume_adi': 679.0, 'volume_obv': 562.0, 'volume_cmf': 619.0, 'volume_fi': 403.0, 'volume_em': 749.0, 'volume_sma_em': 390.0, 'volume_vpt': 619.0, 'volume_vwap': 189.0, 'volume_mfi': 476.0, 'volume_nvi': 292.0, 'volatility_bbm': 73.0, 'volatility_bbh': 198.0, 'volatility_bbl': 199.0, 'volatility_bbw': 289.0, 'volatility_bbp': 251.0, 'volatility_kcc': 92.0, 'volatility_kch': 69.0, 'volatility_kcl': 65.0, 'volatility_kcw': 335.0, 'volatility_kcp': 312.0, 'volatility_dcl': 11.0, 'volatility_dch': 22.0, 'volatility_dcm': 15.0, 'volatility_dcw': 242.0, 'volatility_dcp': 260.0, 'volatility_atr': 257.0, 'volatility_ui': 244.0, 'trend_macd': 169.0, 'trend_macd_signal': 116.0, 'trend_macd_diff': 284.0, 'trend_sma_fast': 20.0, 'trend_sma_slow': 54.0, 'trend_ema_fast': 58.0, 'trend_ema_slow': 33.0, 'trend_vortex_ind_pos': 309.0, 'trend_vortex_ind_neg': 228.0, 'trend_vortex_ind_diff': 109.0, 'trend_trix': 61.0, 'trend_mass_index': 242.0, 'trend_dpo': 567.0, 'trend_kst': 91.0, 'trend_kst_sig': 175.0, 'trend_kst_diff': 224.0, 'trend_ichimoku_conv': 42.0, 'trend_ichimoku_base': 24.0, 'trend_ichimoku_a': 32.0, 'trend_ichimoku_b': 27.0, 'trend_stc': 151.0, 'trend_adx': 258.0, 'trend_adx_pos': 256.0, 'trend_adx_neg': 268.0, 'trend_cci': 163.0, 'trend_visual_ichimoku_a': 188.0, 'trend_visual_ichimoku_b': 23.0, 'trend_aroon_up': 120.0, 'trend_aroon_down': 141.0, 'trend_aroon_ind': 87.0, 'trend_psar_up': 53.0, 'trend_psar_down': 72.0, 'trend_psar_up_indicator': 29.0, 'trend_psar_down_indicator': 28.0, 'momentum_rsi': 193.0, 'momentum_stoch_rsi': 174.0, 'momentum_stoch_rsi_k': 215.0, 'momentum_stoch_rsi_d': 234.0, 'momentum_tsi': 82.0, 'momentum_uo': 407.0, 'momentum_stoch': 182.0, 'momentum_stoch_signal': 196.0, 'momentum_ao': 172.0, 'momentum_roc': 241.0, 'momentum_ppo': 34.0, 'momentum_ppo_signal': 12.0, 'momentum_ppo_hist': 101.0, 'momentum_pvo': 320.0, 'momentum_pvo_signal': 185.0, 'momentum_pvo_hist': 360.0, 'momentum_kama': 60.0, 'others_dr': 513.0, 'others_dlr': 21.0, 'trend': 136.0, 'weekly': 342.0}

# %%
#forecasting
predictions = pd.Series(model.predict(Test), name = "XGBoost")
predictions.index  =test_set.ds

# %% [markdown]
# #VIZ and assessment

# %%
#Visualization
training_set.index = training_set.ds
test_set.index = test_set.ds

# %%
training_set.y['2022-01-01':].plot(figsize = (9,6), legend = True)
test_set.y.plot(legend = True)
predictions.plot(legend = True)
# Out:
# <Axes: xlabel='ds'>

# %%
#MAPE
def MAPE(y_true, y_pred):
  y_true, y_pred = np.array(y_true), np.array(y_pred)
  return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
MAPE(test_set.y, predictions)
# Out:
# 0.7432914912413228

# %%
#rcParams["figure.figsize"] = 80, 50
#tree.plot_tree(model)

# %% [markdown]
# #Future
