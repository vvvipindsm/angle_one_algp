# %%
#Please reload if changes are made to the functions
# %run Common.ipynb

# %%
x_train,x_test,y_train,y_test = get_data("ASIANPAINT.NS","2010-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed
# (2604, 100, 1) (652, 100, 1) (2604,) (652,)

# %%
model_config = base_model_config()

# %%
input_dim = x_train.shape[1] * x_train.shape[2] 

flattern_x = x_train
flattern_test_x = x_test
flattern_test_y =  y_test.reshape(y_test.shape[0],1)
formated_y = y_train.reshape(y_train.shape[0],)
formated_y.shape,flattern_x.shape
# Out:
# ((2604,), (2604, 100, 1))

# %% [markdown]
# ## 2.2 Epoch and Batch Sizes

# %%
#Initialize the measures
accuracy_measures = {}

for batch_size in range(16,128,16):
    if 16 == 16:
        #Load default configuration
        model_config = base_model_config()
        #Acquire and process input data
        #X,Y = get_data()

        #set epoch to 20
        model_config["EPOCHS"]=20
        #Set batch size to experiment value
        model_config["BATCH_SIZE"] = batch_size
        model_name = "Batch-Size-" + str(batch_size)
        history = create_and_run_model(model_config,flattern_x,formated_y,model_name,flattern_test_x,flattern_test_y,False
        accuracy_measures[model_name] = history.history["accuracy"]
# Out:
# 100
#
# ******************************************************
# Model: "Batch-Size-16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                3232
#
#  batch_normalization (Batch  (None, 32)                128
#  Normalization)
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 1)                 65
#
# =================================================================
# Total params: 5537 (21.63 KB)
# Trainable params: 5473 (21.38 KB)
# Non-trainable params: 64 (256.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# /Users/vipin/opt/anaconda3/envs/my_own/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return dispatch_target(*args, **kwargs)
# 163/163 [==============================] - 2s 7ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 2/20
# 163/163 [==============================] - 1s 3ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 3/20
# 163/163 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 4/20
# 163/163 [==============================] - 1s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 5/20
# 163/163 [==============================] - 1s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 6/20
# 163/163 [==============================] - 1s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 7/20
# 163/163 [==============================] - 1s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 8/20
# 163/163 [==============================] - 1s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 9/20
# 163/163 [==============================] - 1s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 10/20
# 163/163 [==============================] - 1s 3ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 11/20
# 163/163 [==============================] - 1s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 12/20
# 163/163 [==============================] - 1s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 13/20
# 163/163 [==============================] - 1s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 14/20
# 163/163 [==============================] - 1s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 15/20
# 163/163 [==============================] - 1s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 16/20
# 163/163 [==============================] - 1s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 17/20
# 163/163 [==============================] - 1s 3ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 18/20
# 163/163 [==============================] - 1s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 19/20
# 163/163 [==============================] - 1s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 20/20
# 163/163 [==============================] - 1s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# 100
#
# ******************************************************
# Model: "Batch-Size-32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                3232
#
#  batch_normalization_1 (Bat  (None, 32)                128
#  chNormalization)
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 1)                 65
#
# =================================================================
# Total params: 5537 (21.63 KB)
# Trainable params: 5473 (21.38 KB)
# Non-trainable params: 64 (256.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 82/82 [==============================] - 2s 6ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 2/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 3/20
# 82/82 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 4/20
# 82/82 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 5/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 6/20
# 82/82 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 7/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 8/20
# 82/82 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 9/20
# 82/82 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 10/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 11/20
# 82/82 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 12/20
# 82/82 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 13/20
# 82/82 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 14/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 15/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 16/20
# 82/82 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 17/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 18/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 19/20
# 82/82 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 20/20
# 82/82 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# 100
#
# ******************************************************
# Model: "Batch-Size-48"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                3232
#
#  batch_normalization_2 (Bat  (None, 32)                128
#  chNormalization)
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 1)                 65
#
# =================================================================
# Total params: 5537 (21.63 KB)
# Trainable params: 5473 (21.38 KB)
# Non-trainable params: 64 (256.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 55/55 [==============================] - 1s 7ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 2/20
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 3/20
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 4/20
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 5/20
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 6/20
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 7/20
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 8/20
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 9/20
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 10/20
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 11/20
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 12/20
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 13/20
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 14/20
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 15/20
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 16/20
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 17/20
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 18/20
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 19/20
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 20/20
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# 100
#
# ******************************************************
# Model: "Batch-Size-64"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                3232
#
#  batch_normalization_3 (Bat  (None, 32)                128
#  chNormalization)
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 1)                 65
#
# =================================================================
# Total params: 5537 (21.63 KB)
# Trainable params: 5473 (21.38 KB)
# Non-trainable params: 64 (256.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 41/41 [==============================] - 2s 13ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 2/20
# 41/41 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 3/20
# 41/41 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 4/20
# 41/41 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 5/20
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 6/20
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 7/20
# 41/41 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 8/20
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 9/20
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 10/20
# 41/41 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 11/20
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 12/20
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 13/20
# 41/41 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 14/20
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 15/20
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 16/20
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 17/20
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 18/20
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 19/20
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 20/20
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# 100
#
# ******************************************************
# Model: "Batch-Size-80"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                3232
#
#  batch_normalization_4 (Bat  (None, 32)                128
#  chNormalization)
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 1)                 65
# =================================================================
# Total params: 5537 (21.63 KB)
# Trainable params: 5473 (21.38 KB)
# Non-trainable params: 64 (256.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 33/33 [==============================] - 2s 15ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 2/20
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 3/20
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 4/20
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 5/20
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 6/20
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 7/20
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 8/20
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 9/20
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 10/20
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 11/20
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 12/20
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 13/20
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 14/20
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 15/20
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 16/20
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 17/20
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 18/20
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 19/20
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 20/20
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# 100
#
# ******************************************************
# Model: "Batch-Size-96"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                3232
#
#  batch_normalization_5 (Bat  (None, 32)                128
#  chNormalization)
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 1)                 65
#
# =================================================================
# Total params: 5537 (21.63 KB)
# Trainable params: 5473 (21.38 KB)
# Non-trainable params: 64 (256.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 28/28 [==============================] - 2s 14ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 2/20
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 3/20
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 4/20
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 5/20
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 6/20
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 7/20
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 8/20
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 9/20
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 10/20
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 11/20
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 12/20
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 13/20
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 14/20
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 15/20
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 16/20
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 17/20
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 18/20
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 19/20
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 20/20
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# 100
#
# ******************************************************
# Model: "Batch-Size-112"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                3232
#
#  batch_normalization_6 (Bat  (None, 32)                128
#  chNormalization)
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#  Output-Layer (Dense)        (None, 1)                 65
#
# =================================================================
# Total params: 5537 (21.63 KB)
# Trainable params: 5473 (21.38 KB)
# Non-trainable params: 64 (256.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 24/24 [==============================] - 1s 14ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 2/20
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 3/20
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 4/20
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 5/20
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 6/20
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 7/20
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 8/20
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 9/20
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 10/20
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 11/20
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 12/20
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 13/20
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 14/20
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 15/20
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 16/20
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 17/20
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 18/20
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 19/20
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015
# Epoch 20/20
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0015

# %%
plot_graph(accuracy_measures, "Compare Batch Size and Epoch")

# %% [markdown]
# ## 2.3. Layers in a Network

# %%
accuracy_measures = {}
layer_list =[]
for layer_count in range(1,6):
    
    #32 nodes in each layer
    layer_list.append(32)
    
    model_config = base_model_config()
    #X,Y = get_data()
    
    model_config["HIDDEN_NODES"] = layer_list
    model_name = "Layers-" + str(layer_count)
    #history=create_and_run_model(model_config,X,Y,model_name)
    history = create_and_run_model(model_config,x_train,y_train,model_name,x_test,x_train)

    accuracy_measures[model_name] = history.history["accuracy"]
# Out:
# ******************************************************
# Model: "Layers-1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                672
#
#  Output-Layer (Dense)        (None, 2)                 66
#
# =================================================================
# Total params: 738 (2.88 KB)
# Trainable params: 738 (2.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
# ******************************************************
# Model: "Layers-2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                672
#
#  batch_normalization_8 (Bat  (None, 32)                128
#  chNormalization)
#
#  Dense-Layer-1 (Dense)       (None, 32)                1056
#
#  Output-Layer (Dense)        (None, 2)                 66
#
# =================================================================
# Total params: 1922 (7.51 KB)
# Trainable params: 1858 (7.26 KB)
# Non-trainable params: 64 (256.00 Byte)
# _________________________________________________________________
#
# ******************************************************
# Model: "Layers-3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                672
#
#  batch_normalization_9 (Bat  (None, 32)                128
#  chNormalization)
#
#  Dense-Layer-1 (Dense)       (None, 32)                1056
#
#  batch_normalization_10 (Ba  (None, 32)                128
#  tchNormalization)
#
#  Dense-Layer-2 (Dense)       (None, 32)                1056
#
#  Output-Layer (Dense)        (None, 2)                 66
#
# =================================================================
# Total params: 3106 (12.13 KB)
# Trainable params: 2978 (11.63 KB)
# Non-trainable params: 128 (512.00 Byte)
# _________________________________________________________________
#
# ******************************************************
# Model: "Layers-4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                672
#
#  batch_normalization_11 (Ba  (None, 32)                128
#  tchNormalization)
#
#  Dense-Layer-1 (Dense)       (None, 32)                1056
#
#  batch_normalization_12 (Ba  (None, 32)                128
#  tchNormalization)
#
#  Dense-Layer-2 (Dense)       (None, 32)                1056
#
#  batch_normalization_13 (Ba  (None, 32)                128
#  tchNormalization)
#
#  Dense-Layer-3 (Dense)       (None, 32)                1056
#
#  Output-Layer (Dense)        (None, 2)                 66
#
# =================================================================
# Total params: 4290 (16.76 KB)
# Trainable params: 4098 (16.01 KB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________
#
# ******************************************************
# Model: "Layers-5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                672
#
#  batch_normalization_14 (Ba  (None, 32)                128
#  tchNormalization)
#
#  Dense-Layer-1 (Dense)       (None, 32)                1056
#
#  batch_normalization_15 (Ba  (None, 32)                128
#  tchNormalization)
#
#  Dense-Layer-2 (Dense)       (None, 32)                1056
#
#  batch_normalization_16 (Ba  (None, 32)                128
#  tchNormalization)
#
#  Dense-Layer-3 (Dense)       (None, 32)                1056
#
#  batch_normalization_17 (Ba  (None, 32)                128
#  tchNormalization)
#
#  Dense-Layer-4 (Dense)       (None, 32)                1056
#
#  Output-Layer (Dense)        (None, 2)                 66
#
# =================================================================
# Total params: 5474 (21.38 KB)
# Trainable params: 5218 (20.38 KB)
# Non-trainable params: 256 (1.00 KB)
# _________________________________________________________________

# %%
plot_graph(accuracy_measures, "Compare Hidden Layers")

# %% [markdown]
# ## 2.4 Nodes in a Layer

# %%
accuracy_measures = {}

for node_count in range(8,40,8):
    
    #have 2 hidden layers in the networks
    layer_list =[]
    for layer_count in range(2):
        layer_list.append(node_count)
    
    model_config = base_model_config()
    #X,Y = get_data()
    
    model_config["HIDDEN_NODES"] = layer_list
    model_name = "Nodes-" + str(node_count)
    #history=create_and_run_model(model_config,X,Y, model_name)
    history = create_and_run_model(model_config,x_train,y_train,model_name,x_test,x_train)

    accuracy_measures[model_name] = history.history["accuracy"]
# Out:
# ******************************************************
# Model: "Nodes-8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 8)                 168
#
#  batch_normalization_18 (Ba  (None, 8)                 32
#  tchNormalization)
#
#  Dense-Layer-1 (Dense)       (None, 8)                 72
#
#  Output-Layer (Dense)        (None, 2)                 18
#
# =================================================================
# Total params: 290 (1.13 KB)
# Trainable params: 274 (1.07 KB)
# Non-trainable params: 16 (64.00 Byte)
# _________________________________________________________________
#
# ******************************************************
# Model: "Nodes-16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 16)                336
#
#  batch_normalization_19 (Ba  (None, 16)                64
#  tchNormalization)
#
#  Dense-Layer-1 (Dense)       (None, 16)                272
#
#  Output-Layer (Dense)        (None, 2)                 34
#
# =================================================================
# Total params: 706 (2.76 KB)
# Trainable params: 674 (2.63 KB)
# Non-trainable params: 32 (128.00 Byte)
# _________________________________________________________________
#
# ******************************************************
# Model: "Nodes-24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 24)                504
#
#  batch_normalization_20 (Ba  (None, 24)                96
#  tchNormalization)
#
#  Dense-Layer-1 (Dense)       (None, 24)                600
#
#  Output-Layer (Dense)        (None, 2)                 50
#
# =================================================================
# Total params: 1250 (4.88 KB)
# Trainable params: 1202 (4.70 KB)
# Non-trainable params: 48 (192.00 Byte)
# _________________________________________________________________
#
# ******************************************************
# Model: "Nodes-32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                672
#
#  batch_normalization_21 (Ba  (None, 32)                128
#  tchNormalization)
#
#  Dense-Layer-1 (Dense)       (None, 32)                1056
#
#  Output-Layer (Dense)        (None, 2)                 66
#
# =================================================================
# Total params: 1922 (7.51 KB)
# Trainable params: 1858 (7.26 KB)
# Non-trainable params: 64 (256.00 Byte)
# _________________________________________________________________

# %%
plot_graph(accuracy_measures, "Compare Nodes in a Layer")

# %% [markdown]
# ## 2.5 Choosing Activation Functions

# %%
accuracy_measures = {}

activation_list = ['relu','sigmoid','tanh']

for activation in activation_list:
    
    model_config = base_model_config()
   # X,Y = get_data()
    
    model_config["HIDDEN_ACTIVATION"] = activation
    model_name = "Model-" + activation
    #history=create_and_run_model(model_config,X,Y,model_name)
    history = create_and_run_model(model_config,x_train,y_train,model_name,x_test,x_train)

    accuracy_measures["Model-" + activation] = history.history["accuracy"]
# Out:
# ******************************************************
# Model: "Model-relu"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                672
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 2)                 130
#
# =================================================================
# Total params: 2914 (11.38 KB)
# Trainable params: 2914 (11.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
# ******************************************************
# Model: "Model-sigmoid"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                672
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 2)                 130
#
# =================================================================
# Total params: 2914 (11.38 KB)
# Trainable params: 2914 (11.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
# ******************************************************
# Model: "Model-tanh"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                672
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 2)                 130
#
# =================================================================
# Total params: 2914 (11.38 KB)
# Trainable params: 2914 (11.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
plot_graph(accuracy_measures, "Compare Activiation Functions")

# %% [markdown]
# ## 2.6. Weights Initialization

# %%
accuracy_measures = {}

initializer_list = ['random_normal','zeros','ones',"random_uniform"]
for initializer in initializer_list:
    
    model_config = base_model_config()
   # X,Y = get_data()
    
    model_config["WEIGHTS_INITIALIZER"] = initializer
    model_name = "Model-" + initializer
    history = create_and_run_model(model_config,x_train,y_train,model_name,x_test,x_train)
    
    accuracy_measures[model_name] = history.history["accuracy"]
# Out:
# ******************************************************
# Model: "Model-random_normal"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                672
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 2)                 130
#
# =================================================================
# Total params: 2914 (11.38 KB)
# Trainable params: 2914 (11.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
# ******************************************************
# Model: "Model-zeros"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                672
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 2)                 130
#
# =================================================================
# Total params: 2914 (11.38 KB)
# Trainable params: 2914 (11.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
# ******************************************************
# Model: "Model-ones"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                672
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 2)                 130
#
# =================================================================
# Total params: 2914 (11.38 KB)
# Trainable params: 2914 (11.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
# ******************************************************
# Model: "Model-random_uniform"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense-Layer-0 (Dense)       (None, 32)                672
#
#  Dense-Layer-1 (Dense)       (None, 64)                2112
#
#  Output-Layer (Dense)        (None, 2)                 130
#
# =================================================================
# Total params: 2914 (11.38 KB)
# Trainable params: 2914 (11.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
plot_graph(accuracy_measures, "Compare Weights Initializers")
