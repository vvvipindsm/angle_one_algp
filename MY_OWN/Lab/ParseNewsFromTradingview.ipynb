# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import json
def scrape_website(url):
    # Send an HTTP GET request to the website
    response = requests.get(url)
    current_date = datetime.now().strftime("%d-%m-%Y")

    # Check if the request was successful
    if response.status_code == 200:
        result = []
        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(response.content, 'html.parser')
        a_links = soup.find_all('a')
        
        for x in a_links:
            temp_res = {}
            if x.get('target') == "_blank" and x.get('href').split("/")[1] == "news":
                timDom = x.find("relative-time")
                timeSpliter = timDom.text.strip().split(" ")
                timeSpliterFlag = False
                for tim in timeSpliter:
                    if tim == "hours" or tim == "hour" or tim == "minutes" or tim == "minute":
                        timeSpliterFlag = True;
                        
                if timeSpliterFlag == False:
                    break
                
                article_main = x.find('article')
                #article_main_div = article_main.find('div')
                temp_stocks = []
                stocks_dom = article_main.find_all('img')
                if len(stocks_dom) != 0:
                    for c in stocks_dom:
                        imgSecArr = c.get('src').split("/")
                        imgCurrent = imgSecArr[len(imgSecArr)-1]
                        exactURL = imgCurrent.split(".")
                        #print(exactURL)
                        if exactURL[1] == "svg":
                            temp_stocks.append(exactURL[0])
                temp_res["stocks"] = json.dumps(temp_stocks)         
                article_main_span = article_main.find_all('span')
                temp_res["content"]  = article_main_span[len(article_main_span)-1].text.strip()
                temp_res["date"]  = timDom.get("event-time")
                result.append(temp_res)
                
        return result
    else:
        print(f"Failed to fetch data. Status Code: {response.status_code}")

    return None

# URL of the website from which you want to scrape data
target_url = 'https://in.tradingview.com/markets/stocks-india/news/'

# Fetch FII and DII data from the website
data = scrape_website(target_url)

# Display the extracted data
print(data)
# Out:
# [{'stocks': '[]', 'content': 'Inox Wind Energy gains on block deal in subsidiary firm', 'date': 'Wed, 09 Aug 2023 05:04:39 GMT'}, {'stocks': '["nifty-50", "bse-sensex", "financial"]', 'content': 'Indian shares fall as China deflation, US bank downgrade sour mood', 'date': 'Wed, 09 Aug 2023 04:55:47 GMT'}, {'stocks': '["gujarat-alkalies"]', 'content': "India's Gujarat Alkalies falls most in 3 months as co swings to loss", 'date': 'Wed, 09 Aug 2023 04:54:02 GMT'}, {'stocks': '[]', 'content': 'Utkarsh Small Finance Bank share falls 1% despite strong Q1 numbers', 'date': 'Wed, 09 Aug 2023 04:51:30 GMT'}, {'stocks': '[]', 'content': 'Prestige Estates Projects down as Q1 revenue dips', 'date': 'Wed, 09 Aug 2023 04:46:28 GMT'}, {'stocks': '[]', 'content': 'EPL shares shed 5% as analysts fret over pace of revenue growth', 'date': 'Wed, 09 Aug 2023 04:44:07 GMT'}, {'stocks': '[]', 'content': 'Gujarat Alkalies slides 5% on dismal quarterly earnings', 'date': 'Wed, 09 Aug 2023 04:38:15 GMT'}, {'stocks': '[]', 'content': "India's Century Enka slumps as Q1 profit more than halved", 'date': 'Wed, 09 Aug 2023 04:28:04 GMT'}, {'stocks': '[]', 'content': 'Mishra Dhatu Nigam tanks 8% after high input costs dent margins', 'date': 'Wed, 09 Aug 2023 04:21:40 GMT'}, {'stocks': '[]', 'content': 'Aarti Industries falls 3% on weak Q1 numbers', 'date': 'Wed, 09 Aug 2023 04:19:07 GMT'}, {'stocks': '[]', 'content': 'Adani Ports gains as brokerages raise target on strong Q1 show', 'date': 'Wed, 09 Aug 2023 04:16:02 GMT'}, {'stocks': '[]', 'content': 'Suven Pharma gains on healthy Q1 show, strong operational performance', 'date': 'Wed, 09 Aug 2023 04:12:33 GMT'}, {'stocks': '[]', 'content': '', 'date': 'Wed, 09 Aug 2023 04:09:00 GMT'}, {'stocks': '["godrej"]', 'content': '', 'date': 'Wed, 09 Aug 2023 03:59:00 GMT'}, {'stocks': '[]', 'content': "India's 63 Moons up after June-quarter profit swing", 'date': 'Wed, 09 Aug 2023 03:58:58 GMT'}, {'stocks': '["adani-wilmar-ltd", "adani"]', 'content': "India's Adani Wilmar at over 2-mth low on report Adani Enterprises weighing exit", 'date': 'Wed, 09 Aug 2023 03:54:33 GMT'}, {'stocks': '[]', 'content': 'Buy GBPINR; target of : 105.90 : August 09, 2023: ICICI Direct', 'date': 'Wed, 09 Aug 2023 03:44:13 GMT'}, {'stocks': '[]', 'content': 'Hindalco keeps brokerages upbeat with June quarter earnings', 'date': 'Wed, 09 Aug 2023 03:36:40 GMT'}, {'stocks': '[]', 'content': 'Agri Picks Report August 09, 2023: Geojit', 'date': 'Wed, 09 Aug 2023 03:31:22 GMT'}, {'stocks': '[]', 'content': 'Vivriti Capital to raise funds via public issue - bankers', 'date': 'Wed, 09 Aug 2023 03:14:41 GMT'}, {'stocks': '["US", "SG", "TH", "ID"]', 'content': 'Philippine peso leads gains in Asia FX', 'date': 'Wed, 09 Aug 2023 02:22:11 GMT'}, {'stocks': '[]', 'content': 'ICICI Lombard falls on Rs 273-cr GST liability, show-cause notice from DGGI', 'date': 'Wed, 09 Aug 2023 01:45:28 GMT'}, {'stocks': '[]', 'content': 'Trade Spotlight | Your game plan for Gland Pharma, Indian Bank, Manappuram Finance today', 'date': 'Wed, 09 Aug 2023 01:07:38 GMT'}, {'stocks': '[]', 'content': 'Hot Stocks | Bet on J Kumar Infraprojects, Prudent Corporate Advisory, Cera Sanitaryware for 12-15% return', 'date': 'Wed, 09 Aug 2023 00:44:01 GMT'}, {'stocks': '["adani", "wilmar", "adani-wilmar-ltd"]', 'content': 'Adani Enterprises weighs exiting $6 bln Wilmar venture - Bloomberg News', 'date': 'Tue, 08 Aug 2023 17:47:37 GMT'}, {'stocks': '[]', 'content': 'Cracks firm even as exports are set to drop', 'date': 'Tue, 08 Aug 2023 16:12:36 GMT'}, {'stocks': '[]', 'content': 'Indian gaming site MPL to lay off 350 employees', 'date': 'Tue, 08 Aug 2023 14:05:56 GMT'}, {'stocks': '["johnkeellshldgs-gd", "lolc-finance"]', 'content': 'Sri Lanka shares end higher as industrials, financials rise', 'date': 'Tue, 08 Aug 2023 11:38:27 GMT'}, {'stocks': '["oil-india", "oil-and-natural-gas"]', 'content': "Oil India's Q1 profit rises marginally as lower costs outweigh rev drop", 'date': 'T ...

# %%
dataa = { "data":[]} 


dataa["data"] = data
dataa
# Out:
# {'data': [{'stocks': '[]',
#    'content': 'Inox Wind Energy gains on block deal in subsidiary firm',
#    'date': 'Wed, 09 Aug 2023 05:04:39 GMT'},
#   {'stocks': '["nifty-50", "bse-sensex", "financial"]',
#    'content': 'Indian shares fall as China deflation, US bank downgrade sour mood',
#    'date': 'Wed, 09 Aug 2023 04:55:47 GMT'},
#   {'stocks': '["gujarat-alkalies"]',
#    'content': "India's Gujarat Alkalies falls most in 3 months as co swings to loss",
#    'date': 'Wed, 09 Aug 2023 04:54:02 GMT'},
#   {'stocks': '[]',
#    'content': 'Utkarsh Small Finance Bank share falls 1% despite strong Q1 numbers',
#    'date': 'Wed, 09 Aug 2023 04:51:30 GMT'},
#   {'stocks': '[]',
#    'content': 'Prestige Estates Projects down as Q1 revenue dips',
#    'date': 'Wed, 09 Aug 2023 04:46:28 GMT'},
#   {'stocks': '[]',
#    'content': 'EPL shares shed 5% as analysts fret over pace of revenue growth',
#    'date': 'Wed, 09 Aug 2023 04:44:07 GMT'},
#   {'stocks': '[]',
#    'content': 'Gujarat Alkalies slides 5% on dismal quarterly earnings',
#    'date': 'Wed, 09 Aug 2023 04:38:15 GMT'},
#   {'stocks': '[]',
#    'content': "India's Century Enka slumps as Q1 profit more than halved",
#    'date': 'Wed, 09 Aug 2023 04:28:04 GMT'},
#   {'stocks': '[]',
#    'content': 'Mishra Dhatu Nigam tanks 8% after high input costs dent margins',
#    'date': 'Wed, 09 Aug 2023 04:21:40 GMT'},
#   {'stocks': '[]',
#    'content': 'Aarti Industries falls 3% on weak Q1 numbers',
#    'date': 'Wed, 09 Aug 2023 04:19:07 GMT'},
#   {'stocks': '[]',
#    'content': 'Adani Ports gains as brokerages raise target on strong Q1 show',
#    'date': 'Wed, 09 Aug 2023 04:16:02 GMT'},
#   {'stocks': '[]',
#    'content': 'Suven Pharma gains on healthy Q1 show, strong operational performance',
#    'date': 'Wed, 09 Aug 2023 04:12:33 GMT'},
#   {'stocks': '[]', 'content': '', 'date': 'Wed, 09 Aug 2023 04:09:00 GMT'},
#   {'stocks': '["godrej"]',
#    'content': '',
#    'date': 'Wed, 09 Aug 2023 03:59:00 GMT'},
#   {'stocks': '[]',
#    'content': "India's 63 Moons up after June-quarter profit swing",
#    'date': 'Wed, 09 Aug 2023 03:58:58 GMT'},
#   {'stocks': '["adani-wilmar-ltd", "adani"]',
#    'content': "India's Adani Wilmar at over 2-mth low on report Adani Enterprises weighing exit",
#    'date': 'Wed, 09 Aug 2023 03:54:33 GMT'},
#   {'stocks': '[]',
#    'content': 'Buy GBPINR; target of : 105.90 : August 09, 2023: ICICI Direct',
#    'date': 'Wed, 09 Aug 2023 03:44:13 GMT'},
#   {'stocks': '[]',
#    'content': 'Hindalco keeps brokerages upbeat with June quarter earnings',
#    'date': 'Wed, 09 Aug 2023 03:36:40 GMT'},
#   {'stocks': '[]',
#    'content': 'Agri Picks Report August 09, 2023: Geojit',
#    'date': 'Wed, 09 Aug 2023 03:31:22 GMT'},
#   {'stocks': '[]',
#    'content': 'Vivriti Capital to raise funds via public issue - bankers',
#    'date': 'Wed, 09 Aug 2023 03:14:41 GMT'},
#   {'stocks': '["US", "SG", "TH", "ID"]',
#    'content': 'Philippine peso leads gains in Asia FX',
#    'date': 'Wed, 09 Aug 2023 02:22:11 GMT'},
#   {'stocks': '[]',
#    'content': 'ICICI Lombard falls on Rs 273-cr GST liability, show-cause notice from DGGI',
#    'date': 'Wed, 09 Aug 2023 01:45:28 GMT'},
#   {'stocks': '[]',
#    'content': 'Trade Spotlight | Your game plan for Gland Pharma, Indian Bank, Manappuram Finance today',
#    'date': 'Wed, 09 Aug 2023 01:07:38 GMT'},
#   {'stocks': '[]',
#    'content': 'Hot Stocks | Bet on J Kumar Infraprojects, Prudent Corporate Advisory, Cera Sanitaryware for 12-15% return',
#    'date': 'Wed, 09 Aug 2023 00:44:01 GMT'},
#   {'stocks': '["adani", "wilmar", "adani-wilmar-ltd"]',
#    'content': 'Adani Enterprises weighs exiting $6 bln Wilmar venture - Bloomberg News',
#    'date': 'Tue, 08 Aug 2023 17:47:37 GMT'},
#   {'stocks': '[]',
#    'content': 'Cracks firm even as exports are set to drop',
#    'date': 'Tue, 08 Aug 2023 16:12:36 GMT'},
#   {'stocks': '[]',
#    'content': 'Indian gaming site MPL to lay off 350 employees',
#    'date': 'Tue, 08 Aug 2023 14:05:56 GMT'},
#   {'stocks': '["johnkeellshldgs-gd", "lolc-finance"]',
#    'content': 'Sri Lanka shares end higher as industrials, financials rise',
#    'date': 'Tue, 08 Aug 2023 11:38:27 GMT'},
#   {'stocks': '["oil-india", "oil-and-natural-gas"]',
#    'content': "Oil India's Q1 profit rises marginally as lower costs outweigh rev drop",
#    'date': 'Tue, 08 Aug 2023 11:23:22 GMT'},
#   {'stocks': '[]',
#    'content': "N. Macedonia's Halk Banka completes cap increase",
#    'date': 'Tue, 08 Aug 2023 11:21:10 GMT'},
#   {'stocks': '["softbank"]',
#    'content': 'SoftBank Sinks Deeper in Losses Despite $1.1bn Gain from Vision Fund',
#    'date': 'Tue, 08 Aug 2023 11:20:47 GMT'},
#   {'stocks': '[]', 'content': '', 'date': 'Tue, 08 Aug 2023 10:38:00 GMT'},
#   {'stocks': '[]',
#    'content': 'Infibeam Avenue gain 2% after announcing listing of subsidiary',
#    'date': 'Tue, 08 Aug 2023 10:36:56 GMT'},
#   {'stocks': '[]',
#    'content': "Manappuram Finance gains on Asirvad MFI's strong Q1 show",
#    'date': 'Tue, 08 Aug 2023 10:30:26 GMT'},
#   {'stocks': '["adani", "power-grid", "hindalco", "hero-motocorp"]',
#    'content': 'Indian Equities Slip Lower on Weak Global Cues, Investor Caution Ahead of Domestic Monetary Policy Release',
#    'date': 'Tue, 08 Aug 2023 10:26:18 GMT'},
#   {'stocks': '[]',
#    'content': 'Taking Stock: Sensex, Nifty end lower as investors turn cautious in data-heavy week',
#    'date': 'Tue, 08 Aug 2023 10:23:42 GMT'},
#   {'stocks': '["nifty-50", "bse-sensex", "hindalco"]',
#    'content': 'Indian shares slip in run up to key data, RBI policy',
#    'date': 'Tue, 08 Aug 2023 10:12:46 GMT'},
#   {'stocks': '[]',
#    'content': 'Neutral Aditya Birla Fashion and Retail; target of Rs 190: Motilal Oswal',
#    'date': 'Tue, 08 Aug 2023 10:04:03 GMT'},
#   {'stocks': '[]',
#    'content': 'Buy Mahanagar Gas; target of Rs 1285: Motilal Oswal',
#    'date': 'Tue, 08 Aug 2023 10:03:22 GMT'},
#   {'stocks': '[]',
#    'content': 'Buy Tube Investments of India; target of Rs 3655: Motilal Oswal',
#    'date': 'Tue, 08 Aug 2023 10:02:55 GMT'},
#   {'stocks': '[]',
#    'content': 'Buy Piramal Pharma; target of Rs 125: Motilal Oswal',
#    'date': 'Tue, 08 Aug 2023 10:02:44 GMT'},
#   {'stocks': '[]',
#    'content': 'Buy TCI Express; target of Rs 1900: Motilal Oswal',
#    'date': 'Tue, 08 Aug 2023 10:02:37 GMT'},
#   {'stocks': '[]',
#    'content': 'Buy LIC Housing Finance; target of Rs 500: Motilal Oswal',
#    'date': 'Tue, 08 Aug 2023 10:02:33 GMT'},
#   {'stocks': '[]',
#    'content': 'Buy Devyani International; target of Rs 220: Motilal Oswal',
#    'date': 'Tue, 08 Aug 2023 10:02:29 GMT'},
#   {'stocks': '[]',
#    'content': 'Buy Bank of Baroda; target of Rs 240: Motilal Oswal',
#    'date': 'Tue, 08 Aug 2023 10:02:23 GMT'},
#   {'stocks': '[]',
#    'content': 'Neutral AAVAS Financiers; target of Rs 1680: Motilal Oswal',
#    'date': 'Tue, 08 Aug 2023 10:02:18 GMT'},
#   {'stocks': '[]',
#    'content': 'J Kumar Infra shares scale 52-week high on reporting 18% growth in Q1 profit',
#    'date': 'Tue, 08 Aug 2023 09:55:36 GMT'},
#   {'stocks': '["rategain-travel-techn-ltd", "nifty-50"]',
#    'content': "India's Rategain Travel hits record high as Q1 profit nearly triples",
#    'date': 'Tue, 08 Aug 2023 09:03:10 GMT'},
#   {'stocks': '[]',
#    'content': 'HPL Electric locked at upper circuit on winning Rs 416-crore power project',
#    'date': 'Tue, 08 Aug 2023 08:01:38 GMT'},
#   {'stocks': '[]',
#    'content': 'India Glycols trades 3% higher on Rs 242-cr capacity expansion plan',
#    'date': 'Tue, 08 Aug 2023 07:57:07 GMT'},
#   {'stocks': '[]',
#    'content': "India's RBI may pause in Aug, hike once in 2023 - BofA",
#    'date': 'Tue, 08 Aug 2023 07:50:15 GMT'},
#   {'stocks': '["whirlpool"]',
#    'content': '',
#    'date': 'Tue, 08 Aug 2023 07:41:00 GMT'},
#   {'stocks': '["US", "CN", "sse-composite", "KR"]',
#    'content': 'Asian currencies and equities slip on weak China trade data',
#    'date': 'Tue, 08 Aug 2023 07:23:05 GMT'}]}

# %%
import requests
import json

url = "https://website-development-kerala.com/api_214124524/oi_news.php"

response = requests.post(url, json=dataa)
print(response.status_code)
print(response)
# Out:
# 200
# <Response [200]>
