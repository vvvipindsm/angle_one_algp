# %% [markdown]
# ### Case Study

# %% [markdown]
# FTX allows customers to trade based on the size of Move for Bitcoin. If we can determine a model, which can forecast better than 50/50 accuracy, whether or not Bitcoins move will likely be above it's average, then we have an edge.
#
# The catch is, how to predict whether future volatility will be above or below the rolling average (assuming that the rolling average is where the market adjusts to). Regardless, this will be a significant challenge and we will need state-of-the-art methods, whilst making sure we do not overfit.

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
from stratmanager import StrategyManager
import sklearn.mixture as mix
from ta.momentum import RSIIndicator
import matplotlib.pyplot as plt
import yfinance

# %% [markdown]
# ### Data Extraction and Returns Overview

# %%
# Extract Data
start_date = "2005-01-1"
end_date = "2022-06-1"
    
symbol = "TATAMOTORS.NS"
strat_mgr = StrategyManager(symbol, start_date, end_date)
df = strat_mgr.df.copy()
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close    Volume   Returns  \
# Date
# 2005-01-04  84.122796  84.508423  83.231032  83.520256   9263718 -0.001249
# 2005-01-05  82.990025  83.447959  77.125292  80.933350  20087981 -0.030973
# 2005-01-06  80.499520  81.849217  78.603526  79.246239  15730697 -0.020846
# 2005-01-07  78.426783  80.017490  78.153629  79.173935  10121770 -0.000912
# 2005-01-10  79.824670  79.824670  73.951902  76.321899   8576881 -0.036022
#
#                Range  Bench_C_Rets
# Date
# 2005-01-04  0.015348     -0.007590
# 2005-01-05  0.081979     -0.043483
# 2005-01-06  0.041292     -0.073107
# 2005-01-07  0.023849     -0.066341
# 2005-01-10  0.079413     -0.090500

# %%
# Benchmark Returns Profile
fig = plt.figure(figsize = (15, 3))
plt.plot(df["Bench_C_Rets"].values)
plt.show()

# %%
# Benchmark Returns Profile
fig = plt.figure(figsize = (15, 2))
plt.plot(df["Returns"].values)
plt.show()

# %%
# Benchmark Range Profile
fig = plt.figure(figsize = (15, 2))
plt.plot(df["Range"].values)
plt.show()

# %% [markdown]
# ### Feature Engineering - Feature Expansion

# %%
# Create a copy
df_fe = df.copy()

# %% [markdown]
# ##### Indicators

# %%
# Add RSI
rsi = RSIIndicator(close=df_fe["Close"], window=14).rsi()
df_fe["RSI"] = rsi
df_fe["RSI_Ret"] = df_fe["RSI"] / df_fe["RSI"].shift(1)

# %%
# Add Moving Average
df_fe["MA_12"] = df_fe["Close"].rolling(window=12).mean()
df_fe["MA_21"] = df_fe["Close"].rolling(window=21).mean()

# %%
# Day of Week
df_fe["DOW"] = df_fe.index.dayofweek

# %%
# Rolling Cumulative Returns
df_fe["Roll_Rets"] = df_fe["Returns"].rolling(window=30).sum()

# %%
# Rolling Cumulative Range
df_fe["Avg_Range"] = df_fe["Range"].rolling(window=30).mean()

# %% [markdown]
# ##### Time Intervals

# %%
# Add Time Intervals
t_steps = [1, 2]
t_features = ["Returns", "Range", "RSI_Ret"]
for ts in t_steps:
    for tf in t_features:
        df_fe[f"{tf}_T{ts}"] = df_fe[tf].shift(ts)

# %%
# Show DataFrame
df_fe.tail(3)
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2023-06-29  573.099976  573.099976  573.099976  573.099976         0
# 2023-06-30  588.349976  599.000000  588.000000  595.549988  12488047
# 2023-07-03  600.000000  602.299988  590.000000  590.799988  11131048
#
#              Returns     Range   Bench_C_Rets        RSI  RSI_Ret  ...  \
# Date                                                               ...
# 2023-06-29  0.000000  0.000000  119559.972775  62.812262  1.00000  ...
# 2023-06-30  0.039173  0.018707  125171.896041  70.972834  1.12992  ...
# 2023-07-03 -0.007976  0.020847  124930.196352  67.593082  0.95238  ...
#
#                  MA_21  DOW  Roll_Rets  Avg_Range  Returns_T1  Range_T1  \
# Date
# 2023-06-29  561.809524    3   0.108890   0.020089    0.009245  0.014865
# 2023-06-30  565.107143    4   0.161739   0.019806    0.000000  0.000000
# 2023-07-03  567.754761    0   0.121312   0.019071    0.039173  0.018707
#
#             RSI_Ret_T1  Returns_T2  Range_T2  RSI_Ret_T2
# Date
# 2023-06-29    1.036891    0.014652  0.020079    1.066252
# 2023-06-30    1.000000    0.009245  0.014865    1.036891
# 2023-07-03    1.129920    0.000000  0.000000    1.000000
#
# [3 rows x 21 columns]

# %% [markdown]
# ### Feature Engineering - Feature Scaling

# %%
# Correct for Stationarity
df_fs = df_fe.copy()
df_fs[["Open", "High", "Low", "Volume"]] = df_fs[["Open", "High", "Low", "Volume"]].pct_change()
df_fs
# Out:
#                 Open      High       Low       Close    Volume   Returns  \
# Date
# 2005-01-04       NaN       NaN       NaN   83.520256       NaN -0.001249
# 2005-01-05 -0.013466 -0.012549 -0.073359   80.933350  1.168458 -0.030973
# 2005-01-06 -0.030010 -0.019159  0.019167   79.246239 -0.216910 -0.020846
# 2005-01-07 -0.025748 -0.022379 -0.005724   79.173935 -0.356559 -0.000912
# 2005-01-10  0.017824 -0.002410 -0.053762   76.321899 -0.152630 -0.036022
# ...              ...       ...       ...         ...       ...       ...
# 2023-06-26 -0.017544 -0.003764  0.000179  567.849976 -0.253781  0.014652
# 2023-06-27  0.017857  0.013884  0.019093  573.099976  0.346066  0.009245
# 2023-06-29  0.005439 -0.006587  0.008180  573.099976 -1.000000  0.000000
# 2023-06-30  0.026610  0.045193  0.025999  595.549988       inf  0.039173
# 2023-07-03  0.019801  0.005509  0.003401  590.799988 -0.108664 -0.007976
#
#                Range   Bench_C_Rets        RSI   RSI_Ret  ...       MA_21  \
# Date                                                      ...
# 2005-01-04  0.015348      -0.007590        NaN       NaN  ...         NaN
# 2005-01-05  0.081979      -0.043483        NaN       NaN  ...         NaN
# 2005-01-06  0.041292      -0.073107        NaN       NaN  ...         NaN
# 2005-01-07  0.023849      -0.066341        NaN       NaN  ...         NaN
# 2005-01-10  0.079413      -0.090500        NaN       NaN  ...         NaN
# ...              ...            ...        ...       ...  ...         ...
# 2023-06-26  0.020079  115394.085049  60.577488  1.066252  ...  556.764288
# 2023-06-27  0.014865  116460.958735  62.812262  1.036891  ...  559.223810
# 2023-06-29  0.000000  119559.972775  62.812262  1.000000  ...  561.809524
# 2023-06-30  0.018707  125171.896041  70.972834  1.129920  ...  565.107143
# 2023-07-03  0.020847  124930.196352  67.593082  0.952380  ...  567.754761
#
#             DOW  Roll_Rets  Avg_Range  Returns_T1  Range_T1  RSI_Ret_T1  \
# Date
# 2005-01-04    1        NaN        NaN         NaN       NaN         NaN
# 2005-01-05    2        NaN        NaN   -0.001249  0.015348         NaN
# 2005-01-06    3        NaN        NaN   -0.030973  0.081979         NaN
# 2005-01-07    4        NaN        NaN   -0.020846  0.041292         NaN
# 2005-01-10    0        NaN        NaN   -0.000912  0.023849         NaN
# ...         ...        ...        ...         ...       ...         ...
# 2023-06-26    0   0.070531   0.021437   -0.017037  0.024117    0.895123
# 2023-06-27    1   0.098049   0.020834    0.014652  0.020079    1.066252
# 2023-06-29    3   0.108890   0.020089    0.009245  0.014865    1.036891
# 2023-06-30    4   0.161739   0.019806    0.000000  0.000000    1.000000
# 2023-07-03    0   0.121312   0.019071    0.039173  0.018707    1.129920
#
#             Returns_T2  Range_T2  RSI_Ret_T2
# Date
# 2005-01-04         NaN       NaN         NaN
# 2005-01-05         NaN       NaN         NaN
# 2005-01-06   -0.001249  0.015348         NaN
# 2005-01-07   -0.030973  0.081979         NaN
# 2005-01-10   -0.020846  0.041292         NaN
# ...                ...       ...         ...
# 2023-06-26   -0.020726  0.029039    0.864846
# 2023-06-27   -0.017037  0.024117    0.895123
# 2023-06-29    0.014652  0.020079    1.066252
# 2023-06-30    0.009245  0.014865    1.036891
# 2023-07-03    0.000000  0.000000    1.000000
#
# [4565 rows x 21 columns]

# %% [markdown]
# ### Assess Data for ML Readiness

# %%
# Check for NaN
df_fs.dropna(inplace=True)
print(df_fs.isnull().values.any())
# Out:
# False

# %%
# Check for Inf values
dfobj = df_fs.isin([np.inf, -np.inf])
count = np.isinf(dfobj).values.sum()
count
# Out:
# 0

# %%
# Check for non-numerical objects
df_fs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4536 entries, 2005-02-16 to 2023-07-03
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          4536 non-null   float64
#  1   High          4536 non-null   float64
#  2   Low           4536 non-null   float64
#  3   Close         4536 non-null   float64
#  4   Volume        4536 non-null   float64
#  5   Returns       4536 non-null   float64
#  6   Range         4536 non-null   float64
#  7   Bench_C_Rets  4536 non-null   float64
#  8   RSI           4536 non-null   float64
#  9   RSI_Ret       4536 non-null   float64
#  10  MA_12         4536 non-null   float64
#  11  MA_21         4536 non-null   float64
#  12  DOW           4536 non-null   int32
#  13  Roll_Rets     4536 non-null   float64
#  14  Avg_Range     4536 non-null   float64
#  15  Returns_T1    4536 non-null   float64
#  16  Range_T1      4536 non-null   float64
#  17  RSI_Ret_T1    4536 non-null   float64
#  18  Returns_T2    4536 non-null   float64
#  19  Range_T2      4536 non-null   float64
#  20  RSI_Ret_T2    4536 non-null   float64
# dtypes: float64(20), int32(1)
# memory usage: 761.9 KB

# %%
# Describe DataFrame
df_fs.describe()
# Out:
#               Open         High          Low        Close       Volume  \
# count  4536.000000  4536.000000  4536.000000  4536.000000  4536.000000
# mean      0.000861     0.000759     0.000860   260.971978          inf
# std       0.029049     0.025374     0.028908   149.443659          NaN
# min      -0.167788    -0.184751    -0.278927    23.051958    -1.000000
# 25%      -0.014617    -0.011979    -0.012050   131.248001    -0.264067
# 50%       0.000000    -0.000460     0.001555   230.904221    -0.025490
# 75%       0.015320     0.012131     0.014132   399.137505     0.322396
# max       0.184847     0.202318     0.251701   597.892273          inf
#
#            Returns        Range   Bench_C_Rets          RSI      RSI_Ret  ...  \
# count  4536.000000  4536.000000    4536.000000  4536.000000  4536.000000  ...
# mean      0.000823     0.037374    6710.470285    51.264679     1.004786  ...
# std       0.027869     0.025571   17223.522723    12.858802     0.099398  ...
# min      -0.175827     0.000000       0.050947     9.558073     0.513816  ...
# 25%      -0.013858     0.022405      48.646244    42.332652     0.943715  ...
# 50%       0.000300     0.030931     698.585882    51.204874     1.001052  ...
# 75%       0.014652     0.044307    2502.810885    60.893476     1.053994  ...
# max       0.204467     0.356489  125171.896041    91.791621     1.923258  ...
#
#              MA_21          DOW    Roll_Rets    Avg_Range   Returns_T1  \
# count  4536.000000  4536.000000  4536.000000  4536.000000  4536.000000
# mean    259.881935     1.993827     0.024517     0.037398     0.000825
# std     148.402286     1.413576     0.181750     0.014644     0.027869
# min      25.185191     0.000000    -1.047074     0.018395    -0.175827
# 25%     130.605810     1.000000    -0.072704     0.027747    -0.013858
# 50%     229.405797     2.000000     0.025389     0.033565     0.000300
# 75%     400.911191     3.000000     0.118516     0.042349     0.014652
# max     572.225691     6.000000     0.809081     0.126170     0.204467
#
#           Range_T1   RSI_Ret_T1   Returns_T2     Range_T2   RSI_Ret_T2
# count  4536.000000  4536.000000  4536.000000  4536.000000  4536.000000
# mean      0.037374     1.004794     0.000818     0.037374     1.004775
# std       0.025571     0.099395     0.027863     0.025571     0.099379
# min       0.000000     0.513816    -0.175827     0.000000     0.513816
# 25%       0.022405     0.943715    -0.013858     0.022405     0.943715
# 50%       0.030931     1.001052     0.000300     0.030931     1.001052
# 75%       0.044307     1.053994     0.014630     0.044307     1.053867
# max       0.356489     1.923258     0.204467     0.356489     1.923258
#
# [8 rows x 21 columns]

# %% [markdown]
# ### Save Data

# %%
# Save DataFrame
df_fs.to_csv(f"data/{symbol}.csv")
